# %% [markdown]
# # The analysis of radiation pressure coefficient $\beta$ [1],[2]
#
# Radiation pressure coefficient $\beta$ is the ratio of radiation and gravitational forces felt by an atom. We can also define $\beta$ as the ratio of the outward force of radiation pressure compared to the inner force of gravity. The ratio depends on the brightness of the central star at the wavelengths of the absorption lines of the species. [1] So we can define the ratio as:
#
# $\begin{align}
# \beta \equiv \frac{F_{rad}}{F_{grav}}
# \end{align}$,
#
# where the $F_{grav}$ is defined as
#
# $\begin{align}
# F_{grav} = \frac{G M m}{r^2}
# \end{align}$
#
# and $F_{rad}$ as:
#
# $\begin{align}
# F_{rad} = \frac{1}{c} \sum_{j < k} F_{\lambda} \sigma_{jk} \xrightarrow{\text{if distance-independent}} F_{rad} =\frac{1}{8 \pi c^2} \sum_{j < k} \frac{g_k}{g_j} A_{kj} \lambda_{jk}^4 F_{\lambda}.
# \end{align}$
#
# Both $F_{grav}$ and $F_{rad}$ are inverse square laws so that their ratio is independent of the distance to the star. So the equation for the ratio $\beta$ is:
#
# $\begin{align}
# \beta = \frac{1}{8 \pi c^2} \frac{r^2}{G M m} \sum_{j < k} \frac{g_k}{g_j} A_{kj} \lambda_{jk}^4 \left( F_{\lambda} \frac{R^2 4 \pi}{r^2 4 \pi} \cdot 4 \pi \right) \
# \end{align}, $
#
#
# The parameters from the equations are defined as followed:
# $\sigma_{jk}$ - cross-section for the transition between atomic levels $j$ and $k$ integrated over wavelength [$ cm^2$],
# $c$ - the speed of light [$cm/s$],
# $r$ - distance to the star at a given point in the orbit [$cm$],
# $R$ - radius of the chosen star [$cm$],
# $G$ - gravitational constant [$ cm^{3} \ g^{-1} \  s^{-2} $],
# $M$ - stellar mass [$g$],
# $m$ - mass of the atomic species under consideration [$g$],
# $k$ - higher atomic level of an atom [$dimensionless$],
# $j$ - lower atomic level of an atom [$dimensionless$],
# $g_k$ - statistical weight of level $k$ [$dimensionless$],
# $g_j$ - statistical weight of level $j$ [$dimensionless$],
# $A_{kj}$ - Einstein coefficient for spontaneous emission from level $k$ to $j$ [$s^{-1}$],
# $\lambda_{jk}$ -  the wavelength of the corresponding transition [$nm$],
# $F_{\lambda}$ - stellar flux density per unit wavelength evaluated at the line center [$erg \ s^{-1} \ cm^{-2} \ nm^{-1}$] $\rightarrow$ [$g \ s^{-3} \ nm^{-1} $].
#
# Unit erg is equal to $ \rightarrow [erg] = \left[ \frac{g \cdot cm^2}{s^2} \right]$

# %% [markdown]
# ## Beta ratio uncertainty [2]
#
# The uncertainties in the $\beta$ ratio were calculated using the following expression:
#
# $\begin{align}
#     \left( \frac{\delta \beta}{\beta} \right)^2 =
# \left( \frac{\delta \Phi}{\Phi} \right)^2_{\mathrm{cal}} +
# \frac{1}{\beta^2} \sum_i
# \left( \frac{g_{0,i}}{\sum g_0} \right)^2 \beta_i^2
# \left( \frac{\delta A_{i0}}{A_{i0}} \right)^2,
# \end{align}$
#
# where $\delta \beta$ is the uncertainty of the beta ratio. Here, $\beta$ represents the calculated ratio itself, $\delta \Phi / \Phi$ is the fractional uncertainty in the overall flux calibration, $g_0 / \sum g_0$ is the weighting factor accounting for the contribution of multiple ground states, and $A_{i0}$ is the Einstein coefficient corresponding to the $i$-th transition.
#
# The uncertainty values for the $\beta$ ratio range from $4$% to $7$%. To ensure a conservative estimate. The uncertainties in the Einstein coefficients spanned from as low as $\leq 0.03$% for the strongest transitions to up to $100$% for the weakest ones. The wavelength uncertainties were within the range $4$% to $7$%, while the uncertainties in the weighted averages ranged from $0.3$% to $6$%.
#
# The uncertainties of $\delta A_{i0}$ are taken from NIST database, where we corresponded value to given letters as followed:
# |NIST|Uncertainty |
# |----|------------|
# |AAA | 0.1 \%     |
# | AA | 1 \%       |
# | A+ | 2 \%       |
# | A  | 3 \%       |
# | B+ | 7 \%       |
# | B  | 10 \%      |
# | C+ | 18 \%      |
# | C  | 25 \%      |
# | D+ | 40 \%      |
# | E  | 75 \%      |
# |    | 100 \%     |

# %% [markdown]
# ## Velocity boost before ionization (for neutral atoms) [2]
#
# The number of ionizing stellar photons hitting an atom per unit time is the stellar ionization rate:
#
# $\begin{align}
# \Gamma_* = \int_0^{\inf} \frac{F_{\lambda}}{hc/\lambda} (\sigma_{ion} m) d\lambda\ ,
# \end{align} $
#
# where
# $F_{\lambda}$ - stellar flux density per unit wavelength evaluated at the line center [$erg \ s^{-1} \ cm^{-2} \ nm^{-1}$],
# $h$ - Planck constant [$cm^2 g/s$],
# $c$ - speed of light [$nm/s$],
# $m$ - mass of the atom [$g$],
# $\sigma_{ion}$ - ionization cross-section [$cm^2/g$].
#
#
# The velocity boost before ionization is then
#
# $\begin{align}
# v_{ion} = \beta \frac{GM}{r^2} \frac{1}{\Gamma_*} \ ,
# \end{align} $
#
# where
# $G$ - gravitational constant [$ cm^{3} \ g^{-1} \  s^{-2} $],
# $M$ - stellar mass [$g$],
# $\Gamma_*$ - stellar ionization rate [$1/s$].

# %% [markdown]
# ## Weakening effect on the Flux by the gas cloud between star and atom/ion [3]
#
# Using Beer-Lambert Law:
#
# $\begin{align}
# F_{\lambda,gc} = F_{\lambda} \times e^{-\tau_{\lambda}}
# \end{align}$
#
# where optical depth at wavelength $\tau_{\lambda}$ is
#
# $\begin{align}
# \tau_{\lambda} = N \sigma_{\lambda}
# \end{align}$
#
# For bound-bound absorption (atomic, molecular lines), the cross section at specific wavelenghts is given as
#
# $\begin{align}
# \sigma_{\lambda} = \frac{e^2 \lambda_{tr}^2}{m_e c^2} f_{jk} \Phi(\lambda)
# \end{align}$
#
# where
#
# $\begin{align}
# \Phi(\lambda) = \frac{(\Gamma \lambda^2_{tr})/(4 \pi c)}{(\lambda - \lambda_{tr})^2 + (\Gamma \lambda^2_{tr})/(4 \pi c)}
# \end{align}$
#
# is Lorentzian line profile and damping constant $\Gamma$ is defined as
#
# $\begin{align}
# \Gamma = \sum_k A_{kj}
# \end{align}$
#
#
# The parameters from the equations are defined as followed:
# $F_{\lambda,gc}$ - stellar flux density per unit wavelength with added weakening effect evaluated at the line center [$erg \ s^{-1} \ cm^{-2} \ nm^{-1}$] $\rightarrow$ [$g \ s^{-3} \ nm^{-1} $],
# $F_{\lambda}$ - stellar flux density per unit wavelength evaluated at the line center [$erg \ s^{-1} \ cm^{-2} \ nm^{-1}$] $\rightarrow$ [$g \ s^{-3} \ nm^{-1} $],
# $\tau_{\lambda}$ - optical depth of specific atom/ion at certain wavelength [$unitless$],
# $N$ - column density of specific atom/ion [$cm^{-2}$],
# $\sigma_{\lambda}$ - cross-section of specific atom/ion at certain wavelength [$1/cm^{-2}$],
# $e$ - electron charge [$C$],
# $\lambda_{tr}$ - wavelength of the transition [$cm$],
# $m_e$ - mass of an electron [$g$],
# $c$ - the speed of light [$cm/s$],
# $f_{jk}$ - oscillator strength of the transition [unitless],
# $\Phi(\lambda)$ - line profile function [unitless],
# $\Gamma$ - damping constant [$s^{-1}$],
# $A_{kj}$ - Einstein coefficient of transition [$s^{-1}$],
# $\lambda$ - wavelength region of the flux [$cm$].
#
# Gas species under consideration are from [4],[5].

# %% [markdown]
# ## Estimating the stellar wind strength [6]
#
# Mass-loss rate of B-type stars:
#
# $\begin{align}
# \log \left(\frac{\dot{M}}{1 M_\odot\ \text{ year }^{-1}}\right) = -22.7 + 8.96 \left(\frac{T_{eff}}{10^4 \text{ K}}\right) - 1.42 \left(\frac{T_{eff}}{10^4 \text{ K}}\right)^2.
# \end{align}$
#
# Artificial velocity law:
#
# $\begin{align}
# v(r) = 10^{-3} \sqrt{\frac{5}{3} \frac{k T_{eff}}{m_H}} + 2 \cdot 10^8 \text{ cm/s } \frac{r-R_{star}}{R_{star}} \ ,
# \end{align} $
#
# where $T_{eff}$ is stellar effective temperature, $R_{star}$ stellar radius and $m_H$ is the mass of the hydrogen atom.

# %% [markdown]
# ## Sources for data:
#
# The atomic data can be found from NIST Atomic Spectra Database (https://www.nist.gov/pml/atomic-spectra-database). Recommended from article [2].
#
# Stellar flux can be found from ATLAS model (https://wwwuser.oats.inaf.it/fiorella.castelli/grids/gridp00k2odfnew/fp00k2tab.html)
#
# Getting ionization cross-sections (https://www.nist.gov/pml/xcom-photon-cross-sections-database) --> 6. search database/Element , look at Total Attenuation with coherent scattering
#
# Host star parameters were generated in CMD 3.7 isochrone model (http://stev.oapd.inaf.it/cgi-bin/cmd) --> isochrones and look at 20 Myr
#
#
# ## Literature:
#
# [1] M. Jura, 2015, ''LAMBDA BOO ABUNDANCE PATTERNS: ACCRETION FROM ORBITING SOURCE''
# [2] R. Fernandez et al., 2005, ''BRAKING THE GAS IN THE β PICTORIS DISK!''
# [3] ASTR 605 Lecture series about Interstellar Medium, Spring 2010, ch. 16 (http://astronomy.nmsu.edu/cwc/Teaching/ASTR605/Lectures/COG.pdf)
# [4] J.-W. Xie et al., 2013,''On the Unusual Gas Composition in the β Pictoris Debris Disk''
# [5] Y. Wu et al., 2025,''Argon in beta Pictoris -- entrapment and release of volatile in disks''
# [6] J. Krticka, 2014, “Mass loss in main-sequence B stars.”

# %% [markdown]
# # 1. step: defining parameters

# %%
# Libraries
import locale
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
from scipy.integrate import quad, nquad
from scipy.interpolate import interp1d
import locale
import math


# pandas dataframe options
from IPython.display import display
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# %%
# Constants (CGS unit system):    
c_nm = 3*10**(17)                  # nm/s
c_cm = 2.99792458*10**(10)         # cm/s
c_m = 299792458                    # m/s
G_cm = 6.67259*10**(-8)            # cm^3/(g*s^2)
j = 0                              # because atoms are in the ground state                                                  
h = 6.6261*10**(-27)               # cm2 g/s     
h_ev = 4.136*10**(-15)             # eV*s      
h_J = 6.62607015*10**(-34)         # J*s 
sun_mass = 1.989*10**(33)          # g  
radius_sun = 6.96*10**(10)         # cm
Na = 6.022e23                      # 1/mol
k = 1.380649e-16                   # Boltzmann constant in erg/K
e = 4.80320425e-10                 # Elementary charge in statC (esu)
m_e = 9.10938356e-28               # Electron mass in g
amu = 1.6605e-24                   # Atomic mass unit in g


# Changeable parameters: 
d_au = 100*1.49597871*10**(13)     # cm, distance of the disc midplane/planet from the host star

# %% [markdown]
# ## Choosing stellar parameters
# ### Age fixed to 20 Myr

# %% [markdown]
# |    | Age          | Mass   | Radius  | Effective Temperature | log g |
# |----|--------------|--------|---------|-----------------------|-------|
# | 1  | 2.000000e+07 | 0.750  | 0.8279  | 4285.525575           | 4.5 |
# | 2  | 2.000000e+07 | 0.900  | 0.9415  | 4543.49443            | 4.5 |
# | 3  | 2.000000e+07 | 1.000  | 1.035   | 4973.361179           | 4.5 |
# | 4  | 2.000000e+07 | 1.200  | 1.341   | 6180.733242           | 4.5 |
# | 5  | 2.000000e+07 | 1.700  | 1.481   | 8078.85847            | 4.5 |
# | 6  | 2.000000e+07 | 2.200  | 1.653   | 10006.91014           | 4.5 |
# | 7  | 2.000000e+07 | 3.200  | 2.055   | 12931.83039           | 4.5 |
# | 8  | 2.000000e+07 | 5.000  | 2.832   | 16950.7922            | 4.5 |
# | 9  | 2.000000e+07 | 6.200  | 3.407   | 19091.93733           | 4.5 |

# %% [markdown]
# ### Example planetary systems

# %% [markdown]
# |    | Name         | Mass   | Radius  | Effective Temperature | log g |
# |----|--------------|--------|---------|-----------------------|-------|
# | 1  | beta Pictoris| 1.750  | 1.800   | 8052                  | 4.5 |
# | 2  | 49 Ceti      | 1.960  | 1.700   | 8720                  | 4.5 |
# | 3  | HD 209458    | 1.148  | 1.200   | 6071                  | 4.5 |
# | 4  | KELT-9       | 2.520  | 2.362   | 10170                 | 4.5 |
# | 5  | Kepler-1520  | 0.760  | 0.710   | 4677                  | 4.5 |

# %% [markdown]
# ### Fernandez+2006 table 4 systems

# %% [markdown]
# |    | Name         | Mass   | Radius  | Effective Temperature | log g |
# |----|--------------|--------|---------|-----------------------|-------|
# | 1  | AU MIC       | 0.500  | 0.750   | 3540                  | 4.5   |
# | 2  | TW Hya       | 0.600  | 0.850   | 3800                  | 4.5   |
# | 3  | HD 107146    | 1.000  | 0.990   | 5850                  | 4.5   |
# | 4  | beta Pictoris| 1.750  | 1.800   | 8052                  | 4.5   |
# | 5  | HR 4796A     | 3.000  | 1.680   | 9378                  | 4.5   |

# %%
######################INITIALISATION##############################
# masses of chosen stars (solar masses)
m1 = 0.750
m2 = 0.900
m3 = 1.000
m4 = 1.2
m5 = 1.7
m6 = 2.2
m7 = 3.2
m8 = 5.0
m9 = 6.2

mbpic = 1.75        # beta Pictoris
mceti = 1.96        # 49 Ceti
mhd = 1.148         # HD 209458
mkelt = 2.52        # KELT-9
mkepler = 0.76      # Kepler-1520

maumic = 0.5        # AU MIC
mtwhya = 0.6        # TW Hya
mhd2 = 1.0          # HD 107146
mhr = 3.0           # HR 4796A


mass = [m1, m2, m3, m4, m5, m6, m7, m8, m9, mbpic, mceti, mhd, mkelt, mkepler, maumic, mtwhya, mhd2, mhr]

# temperatures of chosen stars (K)
T1 = 4250
T2 = 4500
T3 = 5000
T4 = 6000
T5 = 8000
T6 = 10000
T7 = 13000
T8 = 17000
T9 = 19000

Tbpic = 8052        # beta Pictoris
Tceti = 8720        # 49 Ceti
Thd = 6071          # HD 209458
Tkelt = 10170       # KELT-9
Tkepler = 4677      # Kepler-1520

Taumic = 3540        # AU MIC
Ttwhya = 3800        # TW Hya
Thd2 = 5850          # HD 107146
Thr = 9378           # HR 4796A

temp = [T1, T2, T3, T4, T5, T6, T7, T8, T9, Tbpic, Tceti, Thd, Tkelt, Tkepler, Taumic, Ttwhya, Thd2, Thr]

# radiuses of chosen stars (from Solar radius to cm)
r1 = 0.827*radius_sun
r2 = 0.9415*radius_sun
r3 = 1.035*radius_sun
r4 = 1.341*radius_sun
r5 = 1.481*radius_sun
r6 = 1.653*radius_sun
r7 = 2.055*radius_sun
r8 = 2.832*radius_sun
r9 = 3.407*radius_sun

rbpic = 1.8*radius_sun         # beta Pictoris
rceti = 1.7*radius_sun         # 49 Ceti
rhd = 1.2*radius_sun           # HD 209458
rkelt = 2.362*radius_sun       # KELT-9
rkepler = 0.71*radius_sun      # Kepler-1520

raumic = 0.75*radius_sun        # AU MIC
rtwhya = 0.85*radius_sun        # TW Hya
rhd2 = 0.99*radius_sun          # HD 107146
rhr = 1.68*radius_sun           # HR 4796A

radius = [r1, r2, r3, r4, r5, r6, r7, r8, r9, rbpic, rceti, rhd, rkelt, rkepler, raumic, rtwhya, rhd2, rhr]

# %% [markdown]
# ## Choosing the chemical elements

# %%
file_name = ['HI', 'HeI', 'HeII','LiI','LiII', 'LiIII', 'BeI', 'BeII', 'BeIII', 'BI', 'BII', 'BIII', 'CI', 
             'CII', 'CIII', 'NI', 'NII', 'NIII', 'OI', 'OII', 'OIII', 'FI', 'FII', 'NeI', 'NeII', 'NeIII', 
             'NaI', 'NaII', 'NaIII', 'MgI', 'MgII', 'MgIII', 'AlI', 'AlII', 'AlIII', 'SiI', 'SiII', 'SiIII', 
             'PI', 'PII', 'PIII', 'SI', 'S_II', 'S_III', 'ClI', 'ClII', 'ClIII', 'ArI','ArII','ArIII', 'KI', 
             'KII', 'KIII', 'CaI', 'CaII', 'CaIII', 'ScI', 'ScII', 'ScIII', 'TiI', 'TiII', 'TiIII', 'VI', 'VII', 
             'CrI', 'CrII', 'MnI', 'MnII', 'FeI', 'FeII', 'FeIII', 'CoI', 'CoII', 'CoIII', 'Ni_I', 'Ni_II']   # all elements

neut_atom = ['HI', 'HeI','LiI','BeI', 'BI', 'CI', 'NI', 'OI', 'FI', 'NeI', 'NaI', 'MgI', 'AlI', 'SiI', 'PI', 
             'SI', 'ClI', 'ArI', 'KI', 'CaI', 'ScI',  'TiI', 'VI', 'CrI', 'MnI', 'FeI', 'CoI', 'Ni_I'] # only all neutral atoms

# %% [markdown]
# # 2. step: Defining definitions

# %% [markdown]
# ### Reading in the files

# %%
###########################READING IN THE FLUX FILES###################################
# col.0 = FLUX
# col.1 = 
# col.2 = wavelength in nm
# col.3 = frequency nu (s^-1)
# col.4 = Hnu (erg/cm^2/s/Hz/ster) --- second moment of intensity -> half of the intensity, so you have to multiply with 2 to get flux -- thats why 4pi, not 2pi (half a sphere)
# col.5 = Hcont (erg/cm^2/s/Hz/ster) 
# col.6 = Hnu/Hcont

def reading_file(filename,r):
    nm = []
    Ambda = []
    Flambda = []
    with open('ATLAS9 models/'+filename+'.txt', 'r') as raw_data:
        for line in raw_data:
            line = line.strip().split()
            nm.append(locale.atof(line[2]))                                # [nm]
            Ambda.append(locale.atof(line[4]))                             # [erg \ s^-1 \ cm^-2 \ Hz^-1 \ erg]
    for i in range(len(Ambda)):
        F = (c_nm*Ambda[i])/nm[i]**2
        Flambda.append(F * (4*np.pi * r**2)/(4*np.pi *d_au**2)* 4*np.pi)   # [erg \ s^-1 \ cm^-2 \ nm^-1]
    return nm, Flambda

###########################################################################################

###################READING IN THE MASSES OF CHEMICAL ELEMENTS##############################
# col.0 = element name
# col.1 = element isotope number
# col.2 = element mass in g

el_name = []
mass = []
with open('all_elements_masses.txt', 'r') as raw_data:
    for line in raw_data:
        line = line.strip().split()
        el_name.append(line[0])
        mass.append(locale.atof(line[1]))    # unit is grams

###########################################################################################

###################READING IN THE ATOM DATA FROM NIST######################################
# col.0 = Transition wavelength in nm
# col.1 = Einstein coefficient in s^-1
# col.2 = Uncertainty of Einstein coefficient in %
# col.3 = Statistical weight of the ground level 
# col.4 = Statistical weight of the upper level

def find_files(filename):
    filename = filename+'.txt'
    gk = []
    g0 = []
    A = []
    Aunc = [] 
    L = []
    for root, dir, files in os.walk('./Atoms'):
        if filename in files:
            with open('./Atoms/'+filename, 'r') as raw_data:
                for line in raw_data:
                    l = line.strip().split()
                    gk.append(locale.atof(l[4]))
                    g0.append(locale.atof(l[3]))
                    Aunc.append(locale.atof(l[2]))
                    A.append(locale.atof(l[1]))
                    L.append(locale.atof(l[0]))
    return gk, g0, A, Aunc, L

###########################################################################################

###################READING IN THE NEUTRAL ATOM MASSES######################################
# col.0 = element name and isotope
# col.1 = element mass in g

m_neutral = []
with open('neutral_elements_masses.txt', 'r') as raw_data:
    for line in raw_data:
        line = line.strip().split()
        m_neutral.append(locale.atof(line[1]))

###########################################################################################

###################READING IN THE NEUTRAL ATOM CROSS-SECTIONS##############################
# col.0 = wavelength in nm
# col.1 = element cross-section cm^2/g

def find(filename, mass):  # mass in grams
    wavelengths = []
    cross_sections = []
    hc_eVnm = 1239.841984  # Planck constant * c in eV·nm
    for root, dirs, files in os.walk('./Cross-sections'):
        if filename in files:
            with open(os.path.join(root, filename), 'r') as raw_data:
                for line in raw_data:
                    l = line.strip().split()
                    E_MeV = locale.atof(l[0])
                    λ_nm = ((1.24e6) / E_MeV)
                    sigma_cm2_per_g = locale.atof(l[1])
                    sigma_eff = sigma_cm2_per_g * mass  # [cm²]

                    wavelengths.append(λ_nm)
                    cross_sections.append(sigma_eff)
                wavelengths.reverse()
    return wavelengths, cross_sections  # [nm], [cm²]

###########################################################################################

###################READING IN THE ESCAPE VELOCITY DATA#####################################
# col.0 = Temperature [K]
# col.1 = Distance from the star at 0.1 au
# col.2 = Distance from the star at 1 au
# col.3 = Distance from the star at 10 au
# col.4 = Distance from the star at 100 au

temp = []
au1 = []
au2 = []
au3 = []
au4 = []
with open('escape_velocity.txt', 'r') as raw_data:
    for line in raw_data:
        line = line.strip().split()
        temp.append(locale.atof(line[0]))
        au1.append(locale.atof(line[1]))
        au2.append(locale.atof(line[2]))
        au3.append(locale.atof(line[3]))
        au4.append(locale.atof(line[4]))

###########################################################################################

###################READING IN THE FERNANDEZ+2006 RESULTS###################################
# BETA RATIO
# col.0 = Element name
# col.1 = Beta ratio

fernandez_atoms = []
fernandez_beta = []
with open('fernandez2006_beta.txt', 'r') as raw_data:
    for line in raw_data:
        line = line.strip().split()
        fernandez_atoms.append(line[0])
        fernandez_beta.append(locale.atof(line[1]))

# VELOCITY BOOST
# col.0 = Element name
# col.1 = Velocity boost in km/s

fernandez_vel_atoms = []
fernandez_vel=[]
with open('fernandez2006_vel.txt', 'r') as raw_data:
    for line in raw_data:
        line = line.strip().split()
        fernandez_vel_atoms.append(line[0])
        fernandez_vel.append(locale.atof(line[1]))

###########################################################################################

###################READING IN THE CLAIRE+2012 SOLAR FLUX###################################
#Solar Flux predicition from Claire et al, 2012
#Computed for 0.00000 Ga and 1.00000 AU
# col.0 = wavelength in nm
# col.1 = flux (photons/cm^2/s/nm)

s_nm = list()
s_flux = list()
with open('sun_claire2012.dat', 'r') as raw_data:
    for line in raw_data:
        line = line.strip().split()
        s_nm.append(locale.atof(line[0]))
        s_flux.append(locale.atof(line[1]))

###########################################################################################

# %% [markdown]
# ### Calculations

# %%
###################CALCULATING THE SUM PART OF BETA RATIO, EQ (4)##########################
def first_equation(m):
    equation = []
    for el_m in mass:
        equation.append((1/(8*np.pi*c_cm**2))*((d_au**2)/(G_cm*sun_mass*m*el_m)))   # [s^4 cm^-3 g^-1]
    return equation

###########################################################################################

###################CALCULATING THE BETA RATIO, EQ (4)######################################
def beta_func(nm, Flambda, eq):
    beta_values = []
    uncertainties = []

    for y in range(len(file_name)):
        func = find_files(file_name[y])
        gk = func[0]
        g0 = func[1]
        A = func[2]          # [1/s]
        Aunc = func[3]
        L = func[4]          # [nm]
        el = []
        for x in range(len(L)):  # interpolate flux at transition wavelength
            corr = np.interp(L[x], nm, Flambda)
            el.append(gk[x] / g0[x] * A[x] * (L[x])**4 * corr * 1e-21)

        beta = eq[y] * sum(el)
        beta_values.append(beta)

        # --- Uncertainty estimation ---
        delta_phi_over_phi = 0.05  # 5% flux uncertainty
        omega_sum = np.sum(g0)

        sum_term = np.sum([(g0_i / omega_sum)**2 * (dAij)**2
                           for g0_i, dAij in zip(g0, Aunc)])
        
        rel_uncertainty_squared = delta_phi_over_phi**2 + sum_term
        uncertainties.append(beta*np.sqrt(rel_uncertainty_squared))

    return beta_values, uncertainties

###########################################################################################

###################GETTING ONLY THE NEUTRAL ELEMENT BETA RATIO######################################
def getting_neutral_beta(beta_values):
    neut_beta = [beta_values[0],beta_values[1],beta_values[3],beta_values[6],beta_values[9],beta_values[12],beta_values[15],
              beta_values[18],beta_values[21],beta_values[23],beta_values[26],beta_values[29],beta_values[32],beta_values[35],
              beta_values[38],beta_values[41],beta_values[44],beta_values[47],beta_values[50],beta_values[53],beta_values[56],
              beta_values[59],beta_values[62],beta_values[64],beta_values[66],beta_values[68],beta_values[71],beta_values[74]]
    return neut_beta

###########################################################################################

###################CALCULATING THE IONIZATION RATE, EQ (6)#################################
def ionization_rate(nm, Flambda):
    ion_rate = []
    for y in range(len(neut_atom)):
        # Get ionisation cross-section vs wavelength for this species
        cross_wavelengths, cross_sections = find(neut_atom[y], m_neutral[y])  # [nm], [cm²]
        # Define integrand: F_lambda(λ) * λ * σ_eff(λ)
        def integrand(lambda_nm):
            F_interp = np.interp(lambda_nm, nm, Flambda, left=0, right=0)        # [erg/s/cm²/nm]
            sigma_interp = np.interp(lambda_nm, cross_wavelengths, cross_sections, left=0, right=0)  # [cm²]
            return F_interp * lambda_nm * sigma_interp  # [erg·nm²/s/cm²]
        # Integrate over wavelengths (same units: nm)
        int_result, _ = quad(integrand, nm[0], nm[-1])

        # Final ionization rate: divide by hc (in erg·nm)
        Gamma = int_result / (h * c_nm)  # [1/s]
        ion_rate.append(Gamma)

    return ion_rate

###########################################################################################

###################CALCULATING THE VELOCITY BOOST, EQ (7)##################################
def velocity(neutral_beta, ion_rate, mass):
    v_ion = []
    for i in range(len(neutral_beta)):
            answer = neutral_beta[i] * ((G_cm*mass*sun_mass)/(d_au**2)) * (1/ion_rate[i])
            v_ion.append(answer*1e-5) # unit conversion [cm/s] --> [km/s]
    return v_ion

###########################################################################################

# %% [markdown]
# # 3. step: Calculating $\beta$ ratio for chosen stars

# %%
# get wavelengths and fluxes from files
nm1, Flambda1 = reading_file('t4000log45',r1)
nm2, Flambda2 = reading_file('t4500log45',r2)
nm3, Flambda3 = reading_file('t5000log45',r3)
nm4, Flambda4 = reading_file('t6000log45',r4)
nm5, Flambda5 = reading_file('t8000log45',r5)
nm6, Flambda6 = reading_file('t10000log45',r6)
nm7, Flambda7 = reading_file('t13000log45',r7)
nm8, Flambda8 = reading_file('t17000log45',r8)
nm9, Flambda9 = reading_file('t19000log45',r9)

nmbpic, Flambdabpic = reading_file('t8000log45',rbpic)
nmceti, Flambdaceti = reading_file('t8750log45',rceti)
nmhd, Flambdahd = reading_file('t6000log45',rhd)
nmkelt, Flambdakelt = reading_file('t10250log45',rkelt)
nmkepler, Flambdakepler = reading_file('t4750log45',rkepler)

nmaumic, Flambdaaumic = reading_file('t3500log45',raumic)
nmtwhya, Flambdatwhya = reading_file('t3750log45',rtwhya)
nmhd2, Flambdahd2 = reading_file('t5750log45',rhd2)
nmhr, Flambdahr = reading_file('t9250log45',rhr)

# %%
# CALCULATING THE SUM PART OF EQ (4)
eq1_1 = first_equation(m1)
eq1_2 = first_equation(m2)
eq1_3 = first_equation(m3)
eq1_4 = first_equation(m4)
eq1_5 = first_equation(m5)
eq1_6 = first_equation(m6)
eq1_7 = first_equation(m7)
eq1_8 = first_equation(m8)
eq1_9 = first_equation(m9)

eq1_bpic = first_equation(mbpic)
eq1_ceti = first_equation(mceti)
eq1_hd = first_equation(mhd)
eq1_kelt = first_equation(mkelt)
eq1_kepler = first_equation(mkepler)

eq1_aumic = first_equation(maumic)
eq1_twhya = first_equation(mtwhya)
eq1_hd2 = first_equation(mhd2)
eq1_hr = first_equation(mhr)

# %%
# CALCULATING BETA RATIO OF EQ (4)
beta_values1, unc1 = beta_func(nm1, Flambda1, eq1_1)
beta_values2, unc2 = beta_func(nm2, Flambda2, eq1_2)
beta_values3, unc3 = beta_func(nm3, Flambda3, eq1_3)
beta_values4, unc4 = beta_func(nm4, Flambda4, eq1_4)
beta_values5, unc5 = beta_func(nm5, Flambda5, eq1_5)
beta_values6, unc6 = beta_func(nm6, Flambda6, eq1_6)
beta_values7, unc7 = beta_func(nm7, Flambda7, eq1_7)
beta_values8, unc8 = beta_func(nm8, Flambda8, eq1_8)
beta_values9, unc9 = beta_func(nm9, Flambda9, eq1_9)

beta_valuesbpic, uncbpic = beta_func(nmbpic, Flambdabpic, eq1_bpic)
beta_valuesceti, uncceti = beta_func(nmceti, Flambdaceti, eq1_ceti)
beta_valueshd, unchd = beta_func(nmhd, Flambdahd, eq1_hd)
beta_valueskelt, unckelt = beta_func(nmkelt, Flambdakelt, eq1_kelt)
beta_valueskepler, unckepler = beta_func(nmkepler, Flambdakepler, eq1_kepler)

beta_valuesaumic, uncaumic = beta_func(nmaumic, Flambdaaumic, eq1_aumic)
beta_valuestwhya, unctwhya = beta_func(nmtwhya, Flambdatwhya, eq1_twhya)
beta_valueshd2, unchd2 = beta_func(nmhd2, Flambdahd2, eq1_hd2)
beta_valueshr, unchr = beta_func(nmhr, Flambdahr, eq1_hr)

####### results ########
df1 = pd.DataFrame({'Atom': el_name, 'Betavalue1': beta_values1, 'Betaunc1': unc1,'Betavalue2': beta_values2, 'Betaunc2': unc2, 'Betavalue3': beta_values3, 
                        'Betaunc3': unc3, 'Betavalue4': beta_values4, 'Betaunc4': unc4, 'Betavalue5': beta_values5, 'Betaunc5': unc5, 'Betavalue6': beta_values6, 
                        'Betaunc6': unc6, 'Betavalue7': beta_values7, 'Betaunc7': unc7, 'Betavalue8': beta_values8, 'Betaunc8': unc8, 'Betavalue9': beta_values9,
                        'Betaunc9': unc9}).astype(str)
display(df1)
# Out:
#      Atom              Betavalue1                 Betaunc1              Betavalue2                 Betaunc2              Betavalue3                Betaunc3              Betavalue4                Betaunc4              Betavalue5                Betaunc5              Betavalue6                Betaunc6              Betavalue7                Betaunc7              Betavalue8                Betaunc8              Betavalue9                Betaunc9
# 0      HI   3.660468534919739e-13   1.8302453597551504e-14   3.428063238308083e-12    1.714042007192982e-13  3.8540546352223644e-10   1.927038996529232e-11   9.207691344430898e-07  4.6038735742258814e-08    0.002261352616944747   0.0001130683161035296      0.5921380959210794    0.029607084231296873       80.00079663278039       4.000064074231204       3753.767978411201       187.6895364225611      15068.217397507009        753.415435987998
# ...

# %% [markdown]
# # 4. step: Finding velocity boosts for chosen stars neutral atoms

# %%
# get neutral atoms beta ratios
neut_beta1 = getting_neutral_beta(beta_values1)
neut_beta2 = getting_neutral_beta(beta_values2)
neut_beta3 = getting_neutral_beta(beta_values3)
neut_beta4 = getting_neutral_beta(beta_values4)
neut_beta5 = getting_neutral_beta(beta_values5)
neut_beta6 = getting_neutral_beta(beta_values6)
neut_beta7 = getting_neutral_beta(beta_values7)
neut_beta8 = getting_neutral_beta(beta_values8)
neut_beta9 = getting_neutral_beta(beta_values9)

neut_betabpic = getting_neutral_beta(beta_valuesbpic)
neut_betaceti = getting_neutral_beta(beta_valuesceti)
neut_betahd = getting_neutral_beta(beta_valueshd)
neut_betakelt = getting_neutral_beta(beta_valueskelt)
neut_betakepler = getting_neutral_beta(beta_valueskepler)

neut_betaaumic = getting_neutral_beta(beta_valuesaumic)
neut_betatwhya = getting_neutral_beta(beta_valuestwhya)
neut_betahd2 = getting_neutral_beta(beta_valueshd2)
neut_betahr = getting_neutral_beta(beta_valueshr)

# %% [markdown]
# ## Calculating the ionization rate

# %%
# CALCULATING THE IONIZATION RATE
ion_rate1 = ionization_rate(nm1, Flambda1)
ion_rate2 = ionization_rate(nm2, Flambda2)
ion_rate3 = ionization_rate(nm3, Flambda3)
ion_rate4 = ionization_rate(nm4, Flambda4)
ion_rate5 = ionization_rate(nm5, Flambda5)
ion_rate6 = ionization_rate(nm6, Flambda6)
ion_rate7 = ionization_rate(nm7, Flambda7)
ion_rate8 = ionization_rate(nm8, Flambda8)
ion_rate9 = ionization_rate(nm9, Flambda9)

ion_ratebpic = ionization_rate(nmbpic, Flambdabpic)
ion_rateceti = ionization_rate(nmceti, Flambdaceti)
ion_ratehd = ionization_rate(nmhd, Flambdahd)
ion_ratekelt = ionization_rate(nmkelt, Flambdakelt)
ion_ratekepler = ionization_rate(nmkepler, Flambdakepler)

ion_ratebaumic = ionization_rate(nmaumic, Flambdaaumic)
ion_ratetwhya = ionization_rate(nmtwhya, Flambdatwhya)
ion_ratehd2 = ionization_rate(nmhd2, Flambdahd2)
ion_ratehr = ionization_rate(nmhr, Flambdahr)

####### results ########
df2 = pd.DataFrame({'Atom': neut_atom, 'Ion. rate 1 (1/s)': ion_rate1, 'Ion. rate 2 (1/s)': ion_rate2,
                    'Ion. rate 3 (1/s)': ion_rate3, 'Ion. rate  4 (1/s)': ion_rate4, 'Ion. rate 5 (1/s)': ion_rate5, 
                    'Ion. rate 6 (1/s)': ion_rate6, 'Ion. rate 7 (1/s)': ion_rate7, 'Ion. rate 8 (1/s)': ion_rate8, 
                    'Ion. rate 9 (1/s)': ion_rate9}).astype(str)
df2
# Out:
#     Atom       Ion. rate 1 (1/s)       Ion. rate 2 (1/s)       Ion. rate 3 (1/s)      Ion. rate  4 (1/s)       Ion. rate 5 (1/s)       Ion. rate 6 (1/s)       Ion. rate 7 (1/s)       Ion. rate 8 (1/s)       Ion. rate 9 (1/s)
# 0     HI   6.487046857084643e-12  1.2794591753949613e-11   2.340994767081219e-11   7.209941742383663e-11    2.24390841932604e-10   4.681042737302645e-10   1.247169659825207e-09   4.567868251122324e-09  1.1097806269659213e-08
# 1    HeI  1.3002510389268592e-11  2.5659455972296075e-11   4.698376108952211e-11  1.4482156244563557e-10   4.511661999401079e-10   9.420258787301034e-10   2.510790789052214e-09  1.0020122676505883e-08  2.6440392264865555e-08
# 2    LiI  1.9563240625193167e-11  3.8632160669173386e-11   7.080036823103581e-11  2.1844349038658046e-10   6.813119651072044e-10   1.425682260756841e-09  3.7975885526138335e-09   1.884754243653149e-08  5.8314649087853464e-08
# ...

# %% [markdown]
# ## Calculating the velocity boost

# %%
# CALCULATING VELOCITY BOOST BEFORE IONIZATION
v_ion1 = velocity(neut_beta1, ion_rate1, m1)
v_ion2 = velocity(neut_beta2, ion_rate2, m2)
v_ion3 = velocity(neut_beta3, ion_rate3, m3)
v_ion4 = velocity(neut_beta4, ion_rate4, m4)
v_ion5 = velocity(neut_beta5, ion_rate5, m5)
v_ion6 = velocity(neut_beta6, ion_rate6, m6)
v_ion7 = velocity(neut_beta7, ion_rate7, m7)
v_ion8 = velocity(neut_beta8, ion_rate8, m8)
v_ion9 = velocity(neut_beta9, ion_rate9, m9)

v_ionbpic = velocity(neut_betabpic, ion_ratebpic, mbpic)
v_ionceti = velocity(neut_betaceti, ion_rateceti, mceti)
v_ionhd = velocity(neut_betahd, ion_ratehd, mhd)
v_ionkelt = velocity(neut_betakelt, ion_ratekelt, mkelt)
v_ionkepler = velocity(neut_betakepler, ion_ratekepler, mkepler)

v_ionaumic = velocity(neut_betaaumic, ion_ratebaumic, maumic)
v_iontwhya = velocity(neut_betatwhya, ion_ratetwhya, mtwhya)
v_ionhd2 = velocity(neut_betahd2, ion_ratehd2, mhd2)
v_ionhr = velocity(neut_betahr, ion_ratehr, mhr)

####### results ########
df3 = pd.DataFrame({'Atom': neut_atom, 'Velocity 1 (km/s)': v_ion1, 'Velocity 2 (km/s)': v_ion2, 'Velocity 3 (km/s)': v_ion3, 
                    'Velocity 4 (km/s)': v_ion4, 'Velocity 5 (km/s)': v_ion5, 'Velocity 6 (km/s)': v_ion6, 
                    'Velocity 7 (km/s)': v_ion7, 'Velocity 8 (km/s)': v_ion8, 'Velocity 9 (km/s)': v_ion9, }).astype(str)
df3
# Out:
#     Atom       Velocity 1 (km/s)       Velocity 2 (km/s)       Velocity 3 (km/s)       Velocity 4 (km/s)       Velocity 5 (km/s)       Velocity 6 (km/s)       Velocity 7 (km/s)      Velocity 8 (km/s)      Velocity 9 (km/s)
# 0     HI  2.5097433032195935e-11   1.430023909428673e-10   9.763281731587877e-09   9.088216006984775e-06    0.010159924457651381       1.650370587059902       121.7298678049666      2436.701091660078      4992.232752407473
# 1    HeI   7.019411807525088e-35   4.238858689540193e-33  3.1465762213698124e-29   5.796759169069125e-23   4.090449306478056e-16  2.4014766402797012e-11  4.1953334655951313e-07  0.0010458492120436816   0.007431323710601491
# 2    LiI       642.6640776649928       954.4694687651728      1073.6248730872148       1244.768129925501      1262.0436657605285       1252.489120106215       1161.466528711161      679.8228289062922      377.6441513920796
# ...

# %% [markdown]
# # 5. step: Comparing the result with Fernandez et al. 2006

# %% [markdown]
# ## Beta ratio

# %%
# beta ratio comparison with Fernandez+2006 (beta Pic)
fernandez_dict = dict(zip(fernandez_atoms, fernandez_beta))
my_beta_dict = dict(zip(el_name, beta_valuesbpic))
my_comp_beta = {k: my_beta_dict[k] for k in my_beta_dict if k in fernandez_dict}
comp_beta = list(my_comp_beta.values())

####### results ########
df4 = pd.DataFrame({'Atom': fernandez_atoms, 'Our model': comp_beta, 'Fernandez': fernandez_beta }).astype(str)
df4
# Out:
#      Atom               Our model Fernandez
# 0      HI   0.0032449951634257496    0.0016
# 1     LiI      1223.8800184343543     900.0
# 2     BeI      166.11230513540397      62.0
# 3    BeII      181.77638526383106     124.0
# 4      BI       27.85114271066312      30.0
# 5     BII     0.06432758504396599      0.07
# 6    BIII      38.601027859336206      19.0
# 7      CI      0.6556217857109213     0.033
# 8     CII    0.005383166469429597    0.0023
# 9    CIII  2.1038107396754827e-06   8.5e-06
# 10     NI   0.0002603387251136625   0.00021
# 11    NII  3.0609066674568637e-06   7.5e-06
# 12   NIII   4.008597941570422e-07     7e-06
# 13     OI   0.0009262245854651625   0.00033
# 14    OII  1.0372401526696683e-11   3.1e-09
# 15   OIII   4.012184536627183e-12   6.5e-07
# 16    FII   5.112132685780394e-16   3.5e-06
# 17  NeIII  5.8016915628626526e-21     9e-08
# 18    NaI        505.152895794475     360.0
# 19    MgI      164.96409465291015      74.0
# ...

# %%
####### results ########
df4 = pd.DataFrame({'Atom': el_name, 'Our model': uncbpic}).astype(str)
df4
# Out:
#      Atom               Our model
# 0      HI  0.00016225074150017543
# 1     HeI  1.3136832958972995e-17
# 2    HeII  3.0912383248490305e-44
# 3     LiI       62.89984772794872
# 4    LiII  2.1072194202647795e-44
# 5   LiIII  1.8127244201738165e-44
# 6     BeI      22.731257177138104
# 7    BeII       9.176473306180897
# 8   BeIII  1.8921767721505907e-44
# 9      BI       2.090506103969157
# 10    BII    0.003950782211322777
# 11   BIII      1.9497924354078575
# 12     CI    0.047484526929128114
# 13    CII   0.0003215448355559317
# 14   CIII  1.5024213824592254e-07
# 15     NI  1.8268285738752458e-05
# 16    NII   1.619679565694069e-07
# 17   NIII  2.5125217271895586e-08
# 18     OI   6.221139199366466e-05
# 19    OII   7.046273149342051e-13
# 20   OIII   3.059349434969039e-13
# 21     FI   6.661707962639871e-09
# 22    FII   2.723140520503053e-16
# 23    NeI   7.779963061867589e-15
# 24   NeII  1.4199158104709493e-23
# 25  NeIII     4.0681805048483e-22
# ...

# %% [markdown]
# ## Velocity boost

# %%
# velocity boost comparison with Fernandez+2006 (beta Pic)
fernandez_vel_dict = dict(zip(fernandez_vel_atoms, fernandez_vel))
ion_rate_beta = ionization_rate(nmbpic, Flambdabpic) 
velocity_beta = velocity(neut_betabpic, ion_ratebpic, mbpic) 
my_vel_dict = dict(zip(neut_atom, velocity_beta))
my_comp_vel = {k: my_vel_dict[k] for k in my_vel_dict if k in fernandez_vel_dict}
comp_vel = list(my_comp_vel.values())

####### results ########
df5 = pd.DataFrame({'Atom': fernandez_vel_atoms, 'Our model': comp_vel, 'Fernandez': fernandez_vel }).astype(str)
df5
# Out:
#     Atom            Our model Fernandez
# 0    LiI   1262.0436657605273      0.11
# 1    BeI    127.1152893482918      58.0
# 2     BI   16.751280499377877      0.41
# 3    NaI    21.98434126284818       3.3
# 4    MgI    5.167905512324018       1.1
# 5    AlI     4.79507124462119    0.0005
# 6    SiI   0.8532852407537032      0.02
# 7     PI  0.21992943038957483       8.7
# 8     SI  0.04668046215471712       1.5
# 9     KI   3.7799179782933936       0.5
# 10   CaI    6.291100476615903      0.03
# 11   ScI   2.9653484887501373       3.5
# 12   TiI   1.1530085204213076       0.6
# 13    VI    4.535531220635718       0.2
# 14   CrI   0.7522163102234781       0.9
# 15   MnI   0.2426845658179532       0.4
# 16   FeI   0.2130775129043839       0.5
# 17   CoI    0.094023886367911       0.8
# 18  Ni_I  0.00470646408117976       0.3

# %% [markdown]
# # 6. step: Combining ATLAS model Photospheric flux with Solar EUV flux
#
# Estimation of the EUV flux on the beta ratio
#
# ### $\beta$ Pictoris example

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# chosen star
nm_chosen = [nmbpic,nmceti, nmhd, nmkelt, nmkepler]
Flambda_chosen = [Flambdabpic, Flambdaceti, Flambdahd, Flambdakelt, Flambdakepler]
eq1_chosen = [eq1_bpic, eq1_ceti, eq1_hd, eq1_kelt, eq1_kepler]
name_of_plot_file = ["Figure_comp_sun_bpic.pdf", "Figure_comp_sun_ceti.pdf", "Figure_comp_sun_hd.pdf", "Figure_comp_sun_kelt.pdf", "Figure_comp_sun_kepler.pdf"]
beta_valuecomp = [beta_valuesbpic, beta_valuesceti, beta_valueshd, beta_valueskelt, beta_valueskepler]

def _as_scalar_or_short_text(x, max_items=4):
    """
    Turn beta values (scalar / list / np.array) into a short string for the title.
    """
    if x is None:
        return ""
    try:
        arr = np.array(x).ravel()
    except Exception:
        return ""
    if arr.size == 0:
        return ""
    if arr.size == 1:
        return f"β={arr.item():.3g}"
    if arr.size <= max_items:
        return "β=[" + ", ".join(f"{v:.3g}" for v in arr) + "]"
    return f"β: {arr.size} values"

# %%
import numpy as np
import matplotlib.pyplot as plt

# ------------------------------
# 1) Sun spectrum: unit + scale
# ------------------------------
s_flux = np.asarray(s_flux)
s_nm   = np.asarray(s_nm)

photons_to_erg = (s_flux * h * c_cm) / s_nm
sun_flux = photons_to_erg * (d_au**2) / (radius_sun**2) * (8 * np.pi * 10)

# ---------------------------------
# 2) Per-target scale (keep order!)
# ---------------------------------
scales = [5e-8, 5e-8, 1e-8, 1e-7, 1.15e-9]
labels = ["β Pic", "49 Ceti", "HD 209458", "KELT-9", "Kepler-1520"]

# -----------------------------
# 3) Plot all (full + zoom-in)
# -----------------------------
def _overlap_window(x1, x2, pad_frac=0.05):
    a1, b1 = float(np.nanmin(x1)), float(np.nanmax(x1))
    a2, b2 = float(np.nanmin(x2)), float(np.nanmax(x2))
    lo, hi = max(a1, a2), min(b1, b2)
    if not np.isfinite(lo) or not np.isfinite(hi) or lo >= hi:
        mid = np.nanmean(x2)
        rng = (np.nanmax(x2) - np.nanmin(x2)) * 0.1
        return (mid - rng/2, mid + rng/2)
    pad = (hi - lo) * pad_frac
    return lo - pad, hi + pad

for i, (nm, f_lambda, scale, lab) in enumerate(
    zip(nm_chosen, Flambda_chosen, scales, labels)
):
    nm = np.asarray(nm)
    f_lambda = np.asarray(f_lambda)
    sun_scaled = sun_flux * scale

    # ---------- Zoom on overlap ----------
    xlo, xhi = _overlap_window(s_nm, nm, pad_frac=0.05)
    sm = (s_nm >= xlo) & (s_nm <= xhi)
    tm = (nm   >= xlo) & (nm   <= xhi)

    plt.figure(figsize=(10, 6))
    if sm.any():
        plt.plot(s_nm[sm], sun_scaled[sm], label="Sun (scaled)")
    else:
        k = max(1, int(0.1 * len(s_nm)))
        plt.plot(s_nm[:k], sun_scaled[:k], label="Sun (scaled)")

    if tm.any():
        plt.plot(nm[tm], f_lambda[tm], label="ATLAS9 SED")
    else:
        k = max(1, int(0.1 * len(nm)))
        plt.plot(nm[:k], f_lambda[:k], label="ATLAS9 SED")

    plt.yscale("log")
    plt.xlabel("Wavelength (nm)")
    plt.ylabel(r"$F_\lambda$ (arb. units)")
    plt.title(f"{lab}: Overlap (log scale)")
    plt.grid(True, which="both", alpha=0.25)
    plt.legend(frameon=False)
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ensure arrays once
s_nm = np.asarray(s_nm)

# --- YOUR TRANSITIONS (edit these) ---
TRANSITIONS = {
    "β Pic":       111,  
    "49 Ceti":     96,          
    "HD 209458":   170, 
    "KELT-9":      91,  
    "Kepler-1520": 350,          
}

# Optional: SciPy interpolation if available; otherwise fall back to numpy
try:
    from scipy.interpolate import interp1d as _interp1d
    def _interp(x, xp, fp):
        f = _interp1d(xp, fp, kind="linear", bounds_error=False, fill_value=np.nan, assume_sorted=False)
        return f(x)
except Exception:
    def _interp(x, xp, fp):
        xp = np.asarray(xp); fp = np.asarray(fp)
        order = np.argsort(xp)
        xp = xp[order]; fp = fp[order]
        return np.interp(x, xp, fp, left=np.nan, right=np.nan)

def _blend(y_short, y_long, x, x0, width):
    """Blend y_long (short-λ) into y_short (long-λ) around x0 with width."""
    w0 = x0 - width/2
    w1 = x0 + width/2
    ramp = (x - w0) / (w1 - w0)
    w = np.where(x <= w0, 0.0, np.where(x >= w1, 1.0, ramp))
    y_long_use  = np.where(np.isnan(y_long), 0.0, y_long)
    y_short_use = np.where(np.isnan(y_short), 0.0, y_short)
    mask_long   = ~np.isnan(y_long)
    mask_short  = ~np.isnan(y_short)
    y = (1 - w) * y_long_use + w * y_short_use
    only_long  = mask_long & ~mask_short
    only_short = ~mask_long & mask_short
    y[only_long]  = y_long_use[only_long]
    y[only_short] = y_short_use[only_short]
    y[~(mask_long | mask_short)] = np.nan
    return y

def _resolve_transition(cfg, wl_min, wl_max, x0_auto, width_auto):
    """Return (mode, x0, width, w0, w1). mode in {'hard','blend'}."""
    if cfg is None:
        # automatic (use your previous detection)
        x0 = float(np.clip(x0_auto, wl_min, wl_max))
        width = float(max(width_auto, 1e-6))
        return "blend", x0, width, x0 - width/2, x0 + width/2

    # number -> hard cut
    if isinstance(cfg, (int, float, np.floating)):
        x0 = float(np.clip(cfg, wl_min, wl_max))
        return "hard", x0, 0.0, x0, x0

    # pair/list -> blend window [start, end]
    if isinstance(cfg, (list, tuple)) and len(cfg) == 2:
        w0 = float(min(cfg))
        w1 = float(max(cfg))
        w0 = float(np.clip(w0, wl_min, wl_max))
        w1 = float(np.clip(w1, wl_min, wl_max))
        width = max(w1 - w0, 0.0)
        x0 = (w0 + w1) / 2.0
        if width <= 0.0:
            return "hard", x0, 0.0, x0, x0
        return "blend", x0, width, w0, w1

    # dict with centre/width or cut
    if isinstance(cfg, dict):
        if "cut" in cfg:
            x0 = float(np.clip(cfg["cut"], wl_min, wl_max))
            return "hard", x0, 0.0, x0, x0
        if "centre" in cfg:
            x0 = float(np.clip(cfg["centre"], wl_min, wl_max))
            width = float(cfg.get("width", width_auto))
            width = float(max(width, 1e-6))
            w0 = x0 - width/2
            w1 = x0 + width/2
            w0 = float(np.clip(w0, wl_min, wl_max))
            w1 = float(np.clip(w1, wl_min, wl_max))
            x0 = (w0 + w1) / 2.0
            width = max(w1 - w0, 1e-6)
            return "blend", x0, width, w0, w1

    # Fallback to auto if format unrecognised
    x0 = float(np.clip(x0_auto, wl_min, wl_max))
    width = float(max(width_auto, 1e-6))
    return "blend", x0, width, x0 - width/2, x0 + width/2

# ---- Main loop: interpolate, combine with chosen transition, save, and plot zoom ----
GRID_N = 80000
BLEND_FRAC = 0.01  # default blend width (fraction of full span) if you don't specify a width

combined_spec = {}
combined_zoom = {}

for (nm_t, f_t, scale, lab) in zip(nm_chosen, Flambda_chosen, scales, labels):
    nm_t = np.asarray(nm_t)
    f_t  = np.asarray(f_t)

    # Scale Sun for this target
    sun_scaled = sun_flux * scale

    # Common wavelength grid
    wl_min = float(np.nanmin([nm_t.min(), s_nm.min()]))
    wl_max = float(np.nanmax([nm_t.max(), s_nm.max()]))
    nm_common = np.linspace(wl_min, wl_max, GRID_N)

    # Interpolate
    y_atlas = _interp(nm_common, nm_t,  f_t)
    y_sun   = _interp(nm_common, s_nm, sun_scaled)

    # Automatic suggestion (as before)
    valid_atlas = ~np.isnan(y_atlas)
    if np.any(valid_atlas):
        idx_auto = int(np.argmax(valid_atlas))
        x0_auto = nm_common[idx_auto]
    else:
        x0_auto = 0.5 * (wl_min + wl_max)

    width_auto = BLEND_FRAC * (wl_max - wl_min)

    # --- Apply YOUR chosen transition for this target ---
    cfg = TRANSITIONS.get(lab, None)
    mode, x0, width, w0, w1 = _resolve_transition(cfg, wl_min, wl_max, x0_auto, width_auto)

    # Combine
    if mode == "hard" or width <= 0.0:
        # Hard switch at x0
        idx0 = int(np.searchsorted(nm_common, x0, side="left"))
        flux_combined = np.copy(y_sun)
        if idx0 < len(nm_common):
            flux_combined[idx0:] = y_atlas[idx0:]
    else:
        # Smooth blend centred at x0 with given width
        flux_combined = _blend(y_short=y_atlas, y_long=y_sun, x=nm_common, x0=x0, width=width)

    # ---- SAVE for later use ----
    combined_spec[lab] = {
        "nm": nm_common.copy(),
        "F_combined": flux_combined.copy(),
        "F_atlas_interp": y_atlas.copy(),
        "F_sun_interp": y_sun.copy(),
        "transition_mode": mode,
        "transition_nm": float(x0),
        "transition_width": float(width),
        "transition_window": (float(w0), float(w1)),
    }

    # ---------------- Transition zoom plot ----------------
    # Zoom window: around the transition window (or ±5*width for hard cut)
    if mode == "blend":
        span_left  = max(20.0, 2.5 * width)
        span_right = max(20.0, 2.5 * width)
    else:
        span_left  = max(20.0, 0.05 * (wl_max - wl_min))
        span_right = max(20.0, 0.08 * (wl_max - wl_min))

    x_lo = max(wl_min, x0 - span_left)
    x_hi = min(wl_max, x0 + span_right)

    in_full = (nm_common >= x_lo) & (nm_common <= x_hi)
    in_t    = (nm_t      >= x_lo) & (nm_t      <= x_hi)
    in_s    = (s_nm      >= x_lo) & (s_nm      <= x_hi)

    plt.figure(figsize=(10, 6))
    plt.plot(nm_common[in_full], flux_combined[in_full], label="Combined", color="black")
    if np.any(in_t):
        plt.plot(nm_t[in_t], f_t[in_t], label="ATLAS9", linestyle="--")
    if np.any(in_s):
        plt.plot(s_nm[in_s], sun_scaled[in_s], label="Scaled Sun (EUV)", linestyle=":")
    # Visual markers for the transition you chose
    if mode == "hard":
        plt.plot([x0, x0], [1e-20, 1e10], "--k", label=f"Transition: {x0:.1f} nm")
        plt.axvspan(x_lo, x0, alpha=0.15, color="grey", label="Sun-used region")
    else:
        plt.axvspan(w0, w1, alpha=0.12, color="grey", label=f"Blend: {w0:.1f}–{w1:.1f} nm")
        plt.plot([x0, x0], [1e-20, 1e10], ":", color="k")

    plt.xlabel("Wavelength (nm)")
    plt.ylabel(r"Flux  ($F_\lambda$)")
    plt.title(f"{lab}: Transition region (log scale)")
    plt.yscale("log")
    plt.xlim(0,400)
    plt.grid(True, which="both", alpha=0.25)
    plt.legend(frameon=False)
    plt.show()

# %%
import pandas as pd

results = []

for (lab, eq1) in zip(labels, eq1_chosen):

    # --- β calculation ---
    beta_vals, beta_unc = beta_func(combined_spec[lab]["nm"],combined_spec[lab]["F_combined"], eq1)

    for atom, beta_val, beta_err, betabpic in zip(el_name, beta_vals, beta_unc, beta_valuesbpic):
        results.append({
            "Target": lab,
            "Atom": atom,
            "Beta value sun": beta_val,
            "Beta value sun unc": beta_err,
            "Beta value ATLAS9": betabpic
        })

# Create the DataFrame
df_beta_all = pd.DataFrame(results)
df_beta_all = df_beta_all.astype(str)  # if you want everything as strings like your df6
df_beta_all
# Out:
#           Target   Atom          Beta value sun      Beta value sun unc       Beta value ATLAS9
# 0          β Pic     HI    0.005533697003576496  0.00027668652705162326   0.0032449951634257496
# 1          β Pic    HeI   9.209660051348478e-05   4.605833769223713e-06  2.6267940131040177e-16
# 2          β Pic   HeII   0.0005617992310975581  2.8146085410144284e-05    6.17014866804025e-43
# 3          β Pic    LiI      1224.0538467202105       62.90878142450923      1223.8800184343543
# 4          β Pic   LiII   4.363370979735645e-05  2.1817727555421387e-06   4.214270273089916e-43
# 5          β Pic  LiIII  1.7712878839734518e-06   8.869082451885528e-08   3.620280699672679e-43
# 6          β Pic    BeI        166.046305354673      22.722225588610044      166.11230513540397
# 7          β Pic   BeII       182.5107928911386       9.213547824843273      181.77638526383106
# 8          β Pic  BeIII   4.319452370446197e-06  2.1597981748961316e-07   3.784227405489943e-43
# ...

# %%
import numpy as np
import pandas as pd

# --- Per-target transition wavelengths in nm (same order as labels etc.) ---
# If you already defined these elsewhere, reuse that list instead.
transitions = [110.0, 95.0, 150.0, 91.0, 260.0]

# --- Planet/system mass (or whatever 3rd argument velocity() expects) per target ---
# Replace the placeholders with your actual variables (e.g., mbpic, mceti, mhd, mkelt, mkepler)
masses = {
    "β Pic":        mbpic,      # <-- define earlier
    "49 Ceti":      mceti,      # <-- define earlier
    "HD 209458":    mhd,        # <-- define earlier
    "KELT-9":       mkelt,      # <-- define earlier
    "Kepler-1520":  mkepler,    # <-- define earlier
}

# Helper: select values by atom names (robust to ordering)
def values_for_atoms(names_full, values_full, names_subset):
    idx = {name: i for i, name in enumerate(names_full)}
    out = []
    for a in names_subset:
        if a in idx:
            out.append(values_full[idx[a]])
        else:
            out.append(np.nan)
    return np.array(out, dtype=float)

# Ensure arrays
s_nm_arr = np.asarray(s_nm)

all_rows = []

for lab, nm_t, f_t, scale, t, betacomp in zip(
    labels, nm_chosen, Flambda_chosen, scales, transitions, beta_valuecomp
):
    nm_t = np.asarray(nm_t)
    f_t  = np.asarray(f_t)

    # --- Build combined spectrum at fixed transition t (nm) ---
    sun_scaled = sun_flux * scale
    wl_min = float(min(np.nanmin(nm_t), np.nanmin(s_nm_arr)))
    wl_max = float(max(np.nanmax(nm_t), np.nanmax(s_nm_arr)))
    nm_common = np.linspace(wl_min, wl_max, GRID_N)

    y_atlas = _interp(nm_common, nm_t,     f_t)
    y_sun   = _interp(nm_common, s_nm_arr, sun_scaled)

    idx0 = int(np.searchsorted(nm_common, t, side="left"))
    flux_combined = np.copy(y_sun)
    if idx0 < len(nm_common):
        flux_combined[idx0:] = y_atlas[idx0:]

    # --- Ionisation rate from combined spectrum (shape should match neut_atom order) ---
    ion_rate = ionization_rate(nm_common, flux_combined)

    # --- β (photosphere-only) for neutrals: select by name from beta_valuecomp (aligned to el_name) ---
    beta_photo_neut = values_for_atoms(neut_atom, np.asarray(betacomp, dtype=float), neut_atom)

    # --- β (Sun-corrected) for neutrals: read from df_beta_all for this target, align by atom name ---
    sub = df_beta_all.loc[df_beta_all["Target"] == lab, ["Atom", "Beta value sun"]].copy()
    sub["Beta value sun"] = pd.to_numeric(sub["Beta value sun"], errors="coerce")
    beta_sun_map = dict(zip(sub["Atom"], sub["Beta value sun"]))
    beta_sun_neut = np.array([beta_sun_map.get(a, np.nan) for a in neut_atom], dtype=float)

    # --- Mass/parameter for velocity() ---
    m_param = masses[lab]

    # --- Velocity boosts ---
    velocity_beta  = velocity(beta_photo_neut, ion_rate, m_param)  # photospheric β
    velocity_sun   = velocity(beta_sun_neut,   ion_rate, m_param)  # Sun-corrected β

    # --- Collect rows ---
    for atom, v_b, v_s in zip(neut_atom, velocity_beta, velocity_sun):
        all_rows.append({
            "Target": lab,
            "Atom": atom,
            "Velocity boost beta": v_b,
            "Velocity boost sun":  v_s,
        })

# Final tidy table (string-typed like your original df7)
df7_all = pd.DataFrame(all_rows).astype(str)
df7_all
# Out:
#           Target  Atom     Velocity boost beta      Velocity boost sun
# 0          β Pic    HI    0.010067653869127353    0.017168391089316688
# 1          β Pic   HeI   4.052999826041674e-16  0.00014210002916030038
# 2          β Pic   LiI   6.303684094382548e-43      1250.5450321164983
# 3          β Pic   BeI       927.7208806469189      125.86578938421243
# 4          β Pic    BI   2.510027039279101e-43      16.641102950787012
# 5          β Pic    CI  1.7524019947585593e-43     0.31723461794117236
# 6          β Pic    NI       66.47283427434606  0.00010764476805115057
# 7          β Pic    OI       60.62247814653389   0.0003255435607812048
# 8          β Pic    FI  1.0545623410123742e-43  1.6511065574210992e-06
# 9          β Pic   NeI       6.481888773479409  1.4852542482236648e-06
# 10         β Pic   NaI    0.002673411248761465      21.045278063168915
# 11         β Pic   MgI      1.1529358036661812         4.9291662791727
# ...

# %% [markdown]
# # 7. step: Weakening effect on the Flux by the gas cloud between star and atom/ion

# %% [markdown]
# ## Method validation (H-beta line) - $\beta$ Pictoris example

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import wofz

# === Physical constants ===
c_cm     = 2.99792458e10      # speed of light [cm/s]
k_B      = 1.380649e-16       # Boltzmann constant [erg/K]
m_p      = 1.6726219e-24      # proton mass [g]
amu      = 1.66053906660e-24  # atomic mass unit [g]
e_charge = 4.80320427e-10     # elementary charge [esu]
m_e      = 9.10938356e-28     # electron mass [g]

# === Voigt line‐profile φ(λ) in cm⁻¹ ===
def voigt_phi(lambda_cm, lambda0_cm, T, mass_amu, gamma):
    b     = np.sqrt(2 * k_B * T / (mass_amu * m_p))        # Doppler parameter [cm/s]
    delta = (lambda0_cm / c_cm) * b                        # Doppler width [cm]
    x     = (lambda_cm - lambda0_cm) / delta
    a     = gamma * lambda0_cm**2 / (4 * np.pi * c_cm * delta)
    z     = x + 1j * a
    return np.real(wofz(z)) / (delta * np.sqrt(np.pi))

# === Your full gas_species dict ===
gas_species = {
    "H I":   {"wavelength":121.56701, "gamma":5.45778339e8,  "f_lu":4.1641e-1, "N":3.017e-08,   "mass":1},
    "C I":   {"wavelength":127.7556,  "gamma":5.1015e8,      "f_lu":7.81e-2,  "N":4.895e-08, "mass":12},
    "C II":  {"wavelength":68.7056,   "gamma":1.00606e10,   "f_lu":3.34e-1,  "N":2.9e17, "mass":12},
    "C III": {"wavelength":97.703,    "gamma":1.767e9,      "f_lu":7.586e-1, "N":1.3e13, "mass":12},
    "N I":   {"wavelength":120.0223,  "gamma":7.383e8,      "f_lu":8.69e-2,  "N":8e16,   "mass":14},
    "O I":   {"wavelength":130.2168,  "gamma":3.41e8,       "f_lu":5.20e-2,  "N":8.6e17, "mass":16},
    "Na I":  {"wavelength":588.995095,"gamma":6.51979e7,    "f_lu":6.41e-1,  "N":3.4e10, "mass":23},
    "Na II": {"wavelength":17.724,    "gamma":1.03620446e10,"f_lu":7.2e-2,   "N":9.2e12, "mass":23},
    "Mg I":  {"wavelength":285.2127,  "gamma":5.79980254e8, "f_lu":1.80,    "N":2.5e11, "mass":24},
    "Mg II": {"wavelength":279.5528,  "gamma":2.7183e8,     "f_lu":6.08e-1,  "N":2.4e13, "mass":24},
    "Al I":  {"wavelength":396.152,   "gamma":6.0129e8,     "f_lu":1.16e-1,  "N":2.7e12, "mass":27},
    "Al II": {"wavelength":167.07867, "gamma":1.41000328e9, "f_lu":1.77,    "N":4.4e12, "mass":27},
    "Si I":  {"wavelength":184.747,   "gamma":6.156211e8,   "f_lu":1.99e-1,  "N":1.1e13, "mass":28},
    "Si II": {"wavelength":119.328,   "gamma":6.74964551e9, "f_lu":5.75e-1,  "N":1.1e14, "mass":28},
    "P I":   {"wavelength":177.4951,  "gamma":3.35e8,       "f_lu":1.54e-1,  "N":7.0e11, "mass":31},
    "P II":  {"wavelength":130.548,   "gamma":4.76e7,       "f_lu":1.6e-2,   "N":9.2e13, "mass":31},
    "S I":   {"wavelength":142.50301, "gamma":1.6649359e9,  "f_lu":1.61e-1,  "N":5.4e12, "mass":32},
    "S II":  {"wavelength":76.3657,   "gamma":1.2851e10,    "f_lu":4.19e-1,  "N":4.9e13, "mass":32},
    "S III": {"wavelength":69.8731,   "gamma":1.06952154e10,"f_lu":8.50e-1,  "N":4e11,   "mass":32},
    "Ca I":  {"wavelength":422.673,   "gamma":2.864726e8,   "f_lu":1.75,     "N":2.0e9,  "mass":40},
    "Ca II": {"wavelength":393.366,   "gamma":1.47e8,       "f_lu":6.82e-1,  "N":2.6e13, "mass":40},
    "Cr I":  {"wavelength":360.53446, "gamma":2.3098e8,     "f_lu":2.26e-1,  "N":3.5e10, "mass":52},
    "Cr II": {"wavelength":205.559869,"gamma":1.2552e8,     "f_lu":1.03e-1,  "N":4.8e12, "mass":52},
    "Mn I":  {"wavelength":280.106,   "gamma":3.8726004e8,  "f_lu":2.9e-1,   "N":2.4e10, "mass":55},
    "Mn II": {"wavelength":119.717,   "gamma":1.15946e9,    "f_lu":1.48e-1,  "N":3.8e12, "mass":55},
    "Fe I":  {"wavelength":216.67732, "gamma":1.03423483e9, "f_lu":1.5e-1,   "N":4.0e11, "mass":56},
    "Fe II": {"wavelength":114.4926,  "gamma":2.01018e9,    "f_lu":8.3e-2,   "N":1.6e14, "mass":56},
    "Ni I":  {"wavelength":228.998,   "gamma":3.582e8,      "f_lu":1.3e-1,   "N":7.6e10, "mass":59},
    "Ni II": {"wavelength":175.1910,  "gamma":4.8e7,        "f_lu":2.9e-2,   "N":1.5e13, "mass":59},
}

T_gas = 1300  # Kelvin

# === 1) Compute σ₀ and N(τ₀=1) for each species ===
print(f"{'Species':<10s}   {'σ₀ [cm²]':>12s}   {'N(τ₀=1) [cm⁻²]':>16s}")
for name, p in gas_species.items():
    λ0_cm = p["wavelength"] * 1e-7
    φ0    = voigt_phi(np.array([λ0_cm]), λ0_cm, T_gas, p["mass"], p["gamma"])[0]
    σ0    = (np.pi * e_charge**2 / (m_e * c_cm)) * p["f_lu"] * φ0
    N1    = 1.0 / σ0
    print(f"{name:<10s}  {σ0: .3e}        {N1: .3e}")

# === 2) Function to apply multi‐species Voigt absorption with ±cut_nm wings ===
def compute_absorbed_flux(wl_nm, flux, species_dict, T, cut_nm=5.0):
    wl_nm = np.asarray(wl_nm, float)
    flux  = np.asarray(flux,  float)
    λ_cm  = wl_nm * 1e-7
    tau   = np.zeros_like(λ_cm)

    for p in species_dict.values():
        λ0_nm = p["wavelength"]
        Δλ     = np.abs(wl_nm - λ0_nm)
        mask   = Δλ < cut_nm
        if not mask.any():
            continue
        λ0_cm      = λ0_nm * 1e-7
        φ          = np.zeros_like(λ_cm)
        φ[mask]    = voigt_phi(λ_cm[mask], λ0_cm, T, p["mass"], p["gamma"])
        σ          = (np.pi * e_charge**2 / (m_e * c_cm)) * p["f_lu"] * φ
        tau       += p["N"] * σ

    tau_clip = np.clip(tau, None, 700)
    flux_abs = flux * np.exp(-tau_clip)
    return flux_abs, tau

# === 3) Load and apply to full ATLAS9 spectrum ===
wl0, F0 = reading_file('t8000log45', rbpic)  # wavelength [nm], flux [erg/s/cm²/nm]
# ───> ensure numpy arrays for masking & math:
wl0 = np.asarray(wl0, dtype=float)
F0  = np.asarray(F0,  dtype=float)

F_abs, τ_tot = compute_absorbed_flux(wl0, F0, gas_species, T_gas, cut_nm=5.0)

plt.figure(figsize=(10,6))
plt.plot(wl0, F0,      label="Original ATLAS9", alpha=0.6)
plt.plot(wl0, F_abs,   label="After Absorption", color='r', lw=1.2)
plt.xlim(0,1000); plt.ylim(1e-3,5)
plt.xlabel("Wavelength (nm)"); plt.ylabel("Flux (erg s⁻¹ cm⁻² nm⁻¹)")
plt.title("β Pic Model with Multi‐Species Voigt Absorption")
plt.legend(); plt.grid(True); plt.tight_layout()
plt.show()
# Out:
# Species          σ₀ [cm²]     N(τ₀=1) [cm⁻²]
# H I          3.315e+07         3.017e-08
# C I          2.043e+07         4.895e-08
# C II         1.559e+08         6.415e-09
# C III        2.576e+08         3.882e-09
# N I          2.608e+07         3.834e-08
# O I          1.542e+07         6.483e-08
# Na I         5.039e+07         1.984e-08
# Na II        1.856e+08         5.388e-09
# Mg I         2.949e+08         3.390e-09
# Mg II        1.025e+08         9.756e-09
# Al I         1.440e+07         6.946e-08
# Al II        5.210e+08         1.919e-09
# Si I         5.459e+07         1.832e-08
# Si II        2.279e+08         4.388e-09
# P I          4.651e+07         2.150e-08
# P II         6.608e+06         1.513e-07
# S I          6.035e+07         1.657e-08
# S II         2.709e+08         3.691e-09
# S III        6.155e+08         1.625e-09
# Ca I         2.500e+08         4.000e-09
# Ca II        1.055e+08         9.478e-09
# Cr I         4.330e+07         2.310e-08
# ...

# %%
####### results ########
pd.options.display.float_format = '{:.7f}'.format

df8 = pd.DataFrame({'nm': wl0[150:170], 'ATLAS9':F0[150:170], 'Weakened': F_abs[150:170]}).astype(str)
#df9 = pd.DataFrame({'nm': wavelength_atlas9[150:170], 'ATLAS9+sun':flux_sun[150:170], 'Weakened+sun': flux_sun_absorbed_l[150:170]}).astype(str)
    
display(df8)
# Out:
#        nm                  ATLAS9                 Weakened
# 0   119.5  4.7374464487174754e-05    4.67096896277377e-309
# 1   120.5   4.524583470613963e-05   4.461092951549565e-309
# 2   121.5  1.2824684967133058e-05   1.264472455515504e-309
# 3   122.5   5.156790517669109e-05    5.08442865081449e-309
# 4   123.5  0.00011212610488450075    1.10552712627286e-308
# 5   124.5  0.00022102584270662211  2.1792433168992185e-308
# 6   125.5    0.000446684831788493  4.4041679584382834e-308
# 7   126.5    0.000447680228984079  4.4139822528193265e-308
# 8   127.5   0.0006418529179977217     6.3284621601259e-308
# 9   128.5   0.0008788663683811591   8.665338117427049e-308
# 10  129.5    0.001044203703570768   1.029551076300378e-307
# 11  130.5   0.0009548767167462125   9.414775566284974e-308
# 12  131.5   0.0012983813306824189  1.2801619950985043e-307
# 13  132.5    0.001500849919841867   1.479789475036859e-307
# 14  133.5   0.0016511115494028266  1.6279425814777902e-307
# ...

# %% [markdown]
# # 8. step: Comparing beta ratios to other Fernandez+2006 data (Table 4)

# %%
# loading in the fernandes+2006 table 4 data
table4_atoms = []
fernandez_betaaumic = []
fernandez_betatwhya = []
fernandez_betahd2 = []
fernandez_betabpic = []
fernandez_betahr = []
with open('comp_fernandez2006_table4.txt', 'r') as raw_data:
    for line in raw_data:
        line = line.strip().split()
        table4_atoms.append(line[0])
        fernandez_betaaumic.append(locale.atof(line[1]))
        fernandez_betatwhya.append(locale.atof(line[2]))
        fernandez_betahd2.append(locale.atof(line[3]))
        fernandez_betabpic.append(locale.atof(line[4]))
        fernandez_betahr.append(locale.atof(line[5]))

# sort out the desired values/atoms
fernandez_dictaumic = dict(zip(table4_atoms, fernandez_betaaumic))
my_beta_dictaumic = dict(zip(el_name, beta_valuesaumic))
my_comp_betaaumic = {k: my_beta_dictaumic[k] for k in my_beta_dictaumic if k in fernandez_dictaumic}
comp_betaaumic = list(my_comp_betaaumic.values())

fernandez_dicttwhya = dict(zip(table4_atoms, fernandez_betatwhya))
my_beta_dicttwhya = dict(zip(el_name, beta_valuestwhya))
my_comp_betatwhya = {k: my_beta_dicttwhya[k] for k in my_beta_dicttwhya if k in fernandez_dicttwhya}
comp_betatwhya = list(my_comp_betatwhya.values())

fernandez_dicthd2 = dict(zip(table4_atoms, fernandez_betahd2))
my_beta_dicthd2 = dict(zip(el_name, beta_valueshd2))
my_comp_betahd2 = {k: my_beta_dicthd2[k] for k in my_beta_dicthd2 if k in fernandez_dicthd2}
comp_betahd2 = list(my_comp_betahd2.values())

fernandez_dictbpic = dict(zip(table4_atoms, fernandez_betabpic))
my_beta_dictbpic = dict(zip(el_name, beta_valuesbpic))
my_comp_betabpic = {k: my_beta_dictbpic[k] for k in my_beta_dictbpic if k in fernandez_dictbpic}
comp_betabpic = list(my_comp_betabpic.values())

fernandez_dicthr = dict(zip(table4_atoms, fernandez_betahr))
my_beta_dicthr = dict(zip(el_name, beta_valueshr))
my_comp_betahr = {k: my_beta_dicthr[k] for k in my_beta_dicthr if k in fernandez_dicthr}
comp_betahr = list(my_comp_betahr.values())

# results
df10 = pd.DataFrame({'Atom': table4_atoms, 'My Beta (AU Mic)': comp_betaaumic,'Fer. Beta (AU Mic)': fernandez_betaaumic, 
                   'My Beta (TW Hya)': comp_betatwhya, 'Fer. Beta (TW Hya)': fernandez_betatwhya, 
                   'My Beta (HD 107146)': comp_betahd2, 'Fer. Beta (HD 107146)': fernandez_betahd2,
                   'My Beta (Beta Pic)': comp_betabpic, 'Fer. Beta (Beta Pic)': fernandez_betabpic, 
                   'My Beta (HR 4796A)': comp_betahr, 'Fer. Beta (HR 4796A)': fernandez_betahr }).astype(str)
display(df10)
# Out:
#     Atom        My Beta (AU Mic) Fer. Beta (AU Mic)        My Beta (TW Hya) Fer. Beta (TW Hya)     My Beta (HD 107146) Fer. Beta (HD 107146)      My Beta (Beta Pic) Fer. Beta (Beta Pic)    My Beta (HR 4796A) Fer. Beta (HR 4796A)
# 0     CI   8.263425655779748e-11              7e-10  4.5427286563714674e-10              6e-09   3.551412108368221e-05                 1e-05      0.6556217857109213                0.033    14.028373561081617                  3.0
# 1    CII   5.758417097729008e-13              4e-12  2.9359576300205204e-12              2e-11   8.583043381882106e-08                 1e-07    0.005383166469429597               0.0023    1.1348001161111683                 0.01
# 2    NaI      1.3703097381371019                0.6      3.2768924978320673                3.0       71.50722943366925                  12.0        505.152895794475                360.0     391.6459341118969                420.0
# ...

# %% [markdown]
# # 9. step: Add rotational broadening of lines
#
# What you now have
# - A small module: spectral_broadening.py with:
# - convol_by_steps(...) – mirrors your IDL convol_by_steps call (100 Å chunks by default).
# - Rotational broadening (Gray linear limb darkening), instrumental broadening from R, and vmacro as a practical Gaussian approximation.
#
# Notes & parity with your IDL:
# Your convol_by_steps in IDL includes @convol_ber.pro. I reproduced the same idea in Python:
# - Rotational broadening: classical Gray profile with a linear limb-darkening coefficient (default 0.6; tweak via limb_darkening=).
# - Instrumental broadening from resolving power R (Gaussian FWHM = c/R in km/s).
# - Macroturbulence: implemented as a Gaussian with FWHM =vmacro (a standard practical approximation; if you need the exact radial–tangential Gray kernel, say the word and I’ll swap it in).
# - The function processes the spectrum in ~100 Å chunks (default) just like your IDL (“Convolucionamos usando pasos de 100A”). You can change this via step_angstrom=.
# - The output grid is identical to the input (w_out is the same as wavelength_input, just returned for convenience).
# - Everything is normalised so continuum levels stay sensible after convolution.
#
# If you’d like me to:
# - Implement vdop (pure Doppler) or ainst (explicit instrumental FWHM) as separate, mutually exclusive keywords (like in your IDL header), or
# - Replace the macroturbulence with the exact Gray radial–tangential kernel,
# I can extend the module straight away.

# %% [markdown]
# ## Getting HST spectra

# %%
import zipfile
import os

extract_dir = "HST"

# List a sample of the extracted files
files = []
for root, dirs, fnames in os.walk(extract_dir):
    for fname in fnames:
        files.append(os.path.relpath(os.path.join(root, fname), extract_dir))

files[:40]  # show first 40 files for inspection
# Out:
# ['lc9e01010/lc9e01010_x1dsum.fits',
#  'o4xw01030/o4xw01030_x1d.fits',
#  'o4xw01030/o4xw01030_flt.fits',
#  'o6fp02010/o6fp02010_x1d.fits',
#  'o6fp01040/o6fp01040_x1d.fits',
#  'o61q01qtq/o61q01qtq_flt.fits',
#  'o61q01qtq/o61q01qtq_x1d.fits',
#  'o582nabbq/o582nabbq_x1d.fits',
#  'o582nabbq/o582nabbq_flt.fits']

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from astropy.io import fits
from pathlib import Path

# -------------------- parameters --------------------
TRIM_FRAC_DEFAULT = 0.05      # trim 5% off both ends of every grating
TRIM_FRAC = {"G230LB": 0.06, "G430L": 0.12, "G750L": 0.10}

FLUX_LOW_PCT_INSIDE = 3.0     # drop faintest X% before scaling
CLIP_SIGMA = 3.0

# -------------------- inputs --------------------
stis_uvopt = [
    "HST/o61q01qtq/o61q01qtq_x1d.fits",   # G230LB
    #'HST/o4xw01030/o4xw01030_x1d.fits',   # G430L
    "HST/o582nabbq/o582nabbq_x1d.fits",   # G750L
]
fuv_files = [
    "HST/o6fp02010/o6fp02010_x1d.fits",   # E140H
    #"HST/lc9e01010/lc9e01010_x1dsum.fits" # E230H
]
all_files = stis_uvopt + fuv_files

# ATLAS9 model (keep names consistent!)
w_model = np.asarray(nmbpic, float).ravel()
f_model = np.asarray(Flambdabpic, float).ravel()

# -------------------- helpers --------------------
def norm_grat(g): return str(g).upper().strip().split()[0] if g else ""

def air_to_vac_nm(w_nm):
    w_um = w_nm/1000.0
    s2   = 1.0/(w_um**2)
    n    = 1.0 + 0.00008336624212083 + (0.02408926869968/(130.1065924522 - s2)) \
           + (0.0001599740894897/(38.92568793293 - s2))
    return w_nm * n

def read_x1d_segments(fp):
    """Return list of (w_nm, f, grat) from one x1d/x1dsum (CCD in air->vac)."""
    out = []
    with fits.open(fp) as hdul:
        grat = norm_grat(hdul[0].header.get("OPT_ELEM"))
        tab  = hdul[1].data
        for row in tab:
            wA = np.asarray(row["WAVELENGTH"]).ravel().astype(float)
            f  = np.asarray(row["FLUX"]).ravel().astype(float)
            m  = np.isfinite(wA) & np.isfinite(f)
            if not m.any(): 
                continue
            w_nm = wA[m]/10.0
            if grat in ("G430L","G750L"):
                w_nm = air_to_vac_nm(w_nm)
            out.append((w_nm, f[m], grat))
    return out

def read_grouped_by_grating(files):
    by = {}
    for fp in files:
        if not Path(fp).exists():
            print("Missing:", fp); 
            continue
        for w,f,g in read_x1d_segments(fp):
            by.setdefault(g, []).append((w,f))
    # concat & sort
    for g, segs in by.items():
        w = np.concatenate([s[0] for s in segs])
        f = np.concatenate([s[1] for s in segs])
        o = np.argsort(w)
        by[g] = (w[o], f[o])
    return by

def trim_edges(w, f, frac):
    if w.size < 8 or frac <= 0: 
        return w, f
    lo = np.nanquantile(w, frac)
    hi = np.nanquantile(w, 1.0-frac)
    m = np.isfinite(w) & np.isfinite(f) & (w >= lo) & (w <= hi)
    return w[m], f[m]

def best_scale_auto(obs_w, obs_f, mod_w, mod_f,
                    wmin=None, wmax=None, flux_low_pct=0.0, clip_sigma=3.0):
    ow = np.asarray(obs_w, float); of = np.asarray(obs_f, float)
    m  = np.isfinite(ow) & np.isfinite(of)
    ow, of = ow[m], of[m]
    if ow.size == 0: 
        raise ValueError("No finite obs points.")
    if wmin is None: wmin = max(np.nanmin(ow), np.nanmin(mod_w))
    if wmax is None: wmax = min(np.nanmax(ow), np.nanmax(mod_w))
    mwin = (ow >= wmin) & (ow <= wmax)
    if not np.any(mwin): 
        raise ValueError(f"No overlap {wmin}-{wmax} nm.")
    ow, of = ow[mwin], of[mwin]
    if 0.0 < flux_low_pct < 100.0:
        cut  = np.nanpercentile(np.abs(of), flux_low_pct)
        keep = np.abs(of) > cut
        if np.any(keep): 
            ow, of = ow[keep], of[keep]
    fm = np.interp(ow, mod_w, mod_f, left=np.nan, right=np.nan)
    k  = np.isfinite(fm) & np.isfinite(of) & (of != 0)
    if not np.any(k): 
        raise ValueError("No finite model/obs pairs.")
    ratio = fm[k] / of[k]
    med   = np.nanmedian(ratio)
    if clip_sigma and np.isfinite(med):
        mad = np.nanmedian(np.abs(ratio - med))
        sig = 1.4826*mad if mad > 0 else np.nan
        if np.isfinite(sig) and sig > 0:
            keep = np.abs(ratio - med) <= clip_sigma * sig
            if np.any(keep):
                med = np.nanmedian(ratio[keep])
    return med

def interp_nan_outside(x, xp, fp):
    y = np.interp(x, xp, fp, left=np.nan, right=np.nan)
    xmin, xmax = np.nanmin(xp), np.nanmax(xp)
    y[(x < xmin) | (x > xmax)] = np.nan
    return y

# -------------------- read, trim, scale --------------------
by_grat = read_grouped_by_grating(all_files)
print("Gratings:", ", ".join(sorted(by_grat.keys())))

trimmed = {}
for g,(w,f) in by_grat.items():
    frac = TRIM_FRAC.get(g, TRIM_FRAC_DEFAULT)
    wt, ft = trim_edges(w, f, frac=frac)
    trimmed[g] = (wt, ft)
    if wt.size:
        print(f"{g:7s}: kept {wt.size:6d} pts, λ≈{wt.min():.1f}-{wt.max():.1f} nm (trim={frac*100:.1f}%)")

scale_windows = {
    "E140H": (135.0, 140.0),
    "E140M": (135.0, 140.0),
}
scale_windows["G430L"] = (520.0, 560.0)

scaled_segments = []
scales = {}
for g in sorted(trimmed.keys()):
    w,f = trimmed[g]
    if w.size == 0: 
        continue
    try:
        if g in scale_windows:
            s = best_scale_auto(w, f, w_model, f_model,
                                wmin=scale_windows[g][0], wmax=scale_windows[g][1],
                                flux_low_pct=0.0, clip_sigma=CLIP_SIGMA)
        else:
            s = best_scale_auto(w, f, w_model, f_model,
                                wmin=None, wmax=None,
                                flux_low_pct=FLUX_LOW_PCT_INSIDE, clip_sigma=CLIP_SIGMA)
    except Exception as exc:
        print(f"[{g}] scale failed: {exc}; using s=1")
        s = 1.0
    scales[g] = s
    scaled_segments.append((w, f*s, g))
    print(f"Scale {g:7s}: {s:.6g}")

# -------------------- onto ATLAS9 grid & residuals --------------------
contrib = []
for (w,f,g) in scaled_segments:
    contrib.append(interp_nan_outside(w_model, w, f))
M = np.vstack(contrib)                         # [n_gratings, n_lambda]
n_contrib = np.sum(np.isfinite(M), axis=0)
f_obs_on_model = np.nanmedian(M, axis=0)

mask_cov = (n_contrib > 0) & np.isfinite(f_model)
residual_frac = np.full_like(w_model, np.nan, dtype=float)
residual_frac[mask_cov] = (f_obs_on_model[mask_cov] - f_model[mask_cov]) / f_model[mask_cov]

fig, ax1 = plt.subplots(1,1, figsize=(9,6), sharex=True)

ax1.set_yscale("log")
ax1.plot(w_model[mask_cov], f_model[mask_cov], lw=1.0, label="ATLAS9")
ax1.plot(w_model[mask_cov], f_obs_on_model[mask_cov], lw=0.9, label="HST stitched")
ax1.legend()
ax1.set_ylabel("Flux (ATLAS9 scale)")
ax1.set_xlim(100,1050)
# Out:
# Gratings: E230H, G230LB, G750L
# G230LB : kept    900 pts, λ≈175.5-298.9 nm (trim=6.0%)
# G750L  : kept    818 pts, λ≈578.3-977.2 nm (trim=10.0%)
# E230H  : kept  60824 pts, λ≈164.2-188.1 nm (trim=5.0%)
# Scale E230H  : 1.75768e+10
# Scale G230LB : 2.31121e+10
# Scale G750L  : 2.62304e+15
# /tmp/ipykernel_1542863/2864517666.py:167: RuntimeWarning: All-NaN slice encountered
#   f_obs_on_model = np.nanmedian(M, axis=0)
# (100.0, 1050.0)

# %% [markdown]
# ## Adding broadening

# %%
import numpy as np
from idl_rot_broadening import convol_by_steps, convol_ber

# Inputs
wavelength_input = w_model[mask_cov]  # Å
flux_input       = f_obs_on_model[mask_cov]

spectral_resolution = 1000         # R = lambda/FWHM (optional)
Vsini_value = 130.0                   # km/s (optional)
Vmac_value  = 0.0                    # km/s (optional)

# Direct analogue of your IDL call:
wavelength_output, flux_output = convol_by_steps(
    wavelength_input,
    flux_input,
    resol=spectral_resolution,   # or vdop / ain (not together)
    vsini=Vsini_value,
    vmacro=Vmac_value,
    #step=100.0, pad=10.0, beta=1.5, original=False  # tweak if needed
)

plt.figure(figsize=(9,4))
plt.plot(wavelength_input, flux_input, label="Original")
plt.plot(wavelength_output, flux_output, label="Broadened")
plt.xlabel("Wavelength [Å]")
plt.ylabel("Flux [arb]")
plt.legend(loc="best")
plt.xlim(100, 1000)
plt.title("Convolution by steps (Python)")
plt.show()

# %%
# beta ratio from the broadened spectrum
beta_values_bpic_broadened, unc_bpic_broadened = beta_func(wavelength_output, flux_output, eq1_bpic)

# beta ratio comparison with Fernandez+2006 (beta Pic)
fernandez_dict = dict(zip(fernandez_atoms, fernandez_beta))
my_beta_dict_broadened = dict(zip(el_name, beta_values_bpic_broadened))
my_comp_beta_broadened = {k: my_beta_dict_broadened[k] for k in my_beta_dict_broadened if k in fernandez_dict}
comp_beta_broadened = list(my_comp_beta_broadened.values())
# results
df11 = pd.DataFrame({'Atom': fernandez_atoms, 'My Beta (Broadened)': comp_beta_broadened, 'Fer. Beta (Broadened)': fernandez_beta})
df11
# Out:
#      Atom  My Beta (Broadened)  Fer. Beta (Broadened)
# 0      HI           78.5879726              0.0016000
# 1     LiI         1181.6740584            900.0000000
# 2     BeI          132.7322263             62.0000000
# 3    BeII          163.5180550            124.0000000
# 4      BI           40.3616096             30.0000000
# 5     BII            9.3714729              0.0700000
# 6    BIII           43.2643223             19.0000000
# 7      CI            4.9540866              0.0330000
# 8     CII            4.5250254              0.0023000
# 9    CIII            3.3088465              0.0000085
# 10     NI            2.1747620              0.0002100
# 11    NII            1.3310549              0.0000075
# 12   NIII            1.6547557              0.0000070
# 13     OI            0.8822305              0.0003300
# 14    OII            1.0621895              0.0000000
# 15   OIII            0.8859559              0.0000007
# ...

# %%
plt.rcParams.update({'font.size': 12})
plt.rcParams['savefig.dpi'] = 600
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

#changeable parameters:
mz = 10
fz = 12                  # fontsize of the text
cm=1/2.54               # inches to cm
lw = 0.5

# WIDTHS:
    # one column    -> 9.0 cm
    # 2/3 page      -> 13.0 cm
    # entire page   -> 18.0 cm
fig, ax = plt.subplots(constrained_layout=True, figsize=(15.0*cm,15.0*cm))
#########################################################

plt.plot(comp_beta_broadened, fernandez_beta, 'ok', markersize=1)
plt.plot([10**(-10), 10**(10)], [1,1],'--k', linewidth= lw, markersize=mz)
plt.plot([1,1], [10**(-10), 10**(10)],'--k', linewidth= lw, markersize=mz)
plt.plot([10**(-10), 10**(10)], [0.5,0.5],'--', color='tab:grey', linewidth= lw, markersize=mz)
plt.plot([0.5,0.5], [10**(-10), 10**(10)],'--', color='tab:grey', linewidth= lw, markersize=mz)

#for i,txt in enumerate(atoms):
#    plt.text(fernandez_beta[i], my_beta[i], txt, fontsize=7)

##################

plt.plot([1e-10,1e9], [1e-10,1e9], 'r-')

plt.xlabel("Beta ratio (Our model)", fontsize=fz)
plt.ylabel("Beta ratio (Fernandez)", fontsize=fz)

ax = plt.gca()
ax.set_yscale('log')
ax.set_xscale('log')

ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

plt.savefig("Figure_comp_beta_fernandez.pdf", format='pdf',bbox_inches='tight', facecolor = 'white', transparent='false')

plt.show()

# %% [markdown]
# # 10. step: Look into the data
#
# **What species to look at: Be II (1), B III (1), C I (1), Si II (2), P II (1), Ca I (1), Sc II (1), Ni III (3)**

# %%
# get specific lines for chosen elements
#del max  # Removes any accidental reassignment of 'max'

with open('Atoms/BeII.txt', 'r') as raw_data:
    be2_nm = []
    be2_ein_raw = []
    for line in raw_data:
        line = line.strip().split()
        be2_ein_raw.append(locale.atof(line[1]))
        be2_nm.append(locale.atof(line[0]))
    max_v = max(be2_ein_raw)
    be2_ein = [v / max_v for v in be2_ein_raw]

with open('Atoms/BIII.txt', 'r') as raw_data:
    b3_nm = []
    b3_ein_raw = []
    for line in raw_data:
        line = line.strip().split()
        b3_ein_raw.append(locale.atof(line[1]))
        b3_nm.append(locale.atof(line[0]))
    max_v = max(b3_ein_raw)
    b3_ein = [v / max_v for v in b3_ein_raw]

with open('Atoms/CI.txt', 'r') as raw_data:
    c1_nm = []
    c1_ein_raw = []
    for line in raw_data:
        line = line.strip().split()
        c1_ein_raw.append(locale.atof(line[1]))
        c1_nm.append(locale.atof(line[0]))
    max_v = max(c1_ein_raw)
    c1_ein = [v / max_v for v in c1_ein_raw]

with open('Atoms/SiII.txt', 'r') as raw_data:
    si2_nm = []
    si2_ein_raw = []
    for line in raw_data:
        line = line.strip().split()
        si2_ein_raw.append(locale.atof(line[1]))
        si2_nm.append(locale.atof(line[0]))
    max_v = max(si2_ein_raw)
    si2_ein = [v / max_v for v in si2_ein_raw]

with open('Atoms/PII.txt', 'r') as raw_data:
    p2_nm = []
    p2_ein_raw = []
    for line in raw_data:
        line = line.strip().split()
        p2_ein_raw.append(locale.atof(line[1]))
        p2_nm.append(locale.atof(line[0]))
    max_v = max(p2_ein_raw)
    p2_ein = [v / max_v for v in p2_ein_raw]

with open('Atoms/CaI.txt', 'r') as raw_data:
    ca1_nm = []
    ca1_ein_raw = []
    for line in raw_data:
        line = line.strip().split()
        ca1_ein_raw.append(locale.atof(line[1]))
        ca1_nm.append(locale.atof(line[0]))
    max_v = max(ca1_ein_raw)
    ca1_ein = [v / max_v for v in ca1_ein_raw]

with open('Atoms/ScII.txt', 'r') as raw_data:
    sc2_nm = []
    sc2_ein_raw = []
    for line in raw_data:
        line = line.strip().split()
        sc2_ein_raw.append(locale.atof(line[1]))
        sc2_nm.append(locale.atof(line[0]))
    max_v = max(sc2_ein_raw)
    sc2_ein = [v / max_v for v in sc2_ein_raw]

# %%
# graph

import matplotlib as mpl

plt.rcParams.update({'font.size': 9})
plt.rcParams['savefig.dpi'] = 600
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

#changeable parameters:
ymin = 11**(-10)        # y-axis minimum value
ymax = 11**(4)         # y-axis maximum value
xmin = 10              # x-axis minimum value
xmax = 450              # x-axis maximum value
fz = 9                  # fontsize of the text
cm=1/2.54               # inches to cm

#############################################################
#############################################################
# Be II
plt.plot(nm1, Flambda1)
plt.plot(nm2, Flambda2)
plt.plot(nm3, Flambda3)
plt.plot(nm4, Flambda4)
plt.plot(nm5, Flambda5)
plt.plot(nm6, Flambda6)
plt.plot(nm7, Flambda7)
plt.plot(nm8, Flambda8)
plt.plot(nm9, Flambda9)

plt.xlabel("Wavelength [nm]", fontsize=fz)
plt.title('Be II')

ax = plt.gca()
ax.set_yscale('log')

ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

ax.set_ylim(ymin, ymax)
ax.set_xlim(65, 320)

ax2 = ax.twinx()

for i in range(len(be2_nm)):
    ax2.plot((be2_nm[i],be2_nm[i]), (10**(-50),be2_ein[i]), color='black', linestyle='-')

ax2.set_ylim(0,1 )
ax2.tick_params(axis="y",direction="in")
ax2.set_ylabel('Normalized Einstein coefficent', fontsize=fz)
plt.show()
##############################################################
#############################################################
# B III
plt.plot(nm1, Flambda1)
plt.plot(nm2, Flambda2)
plt.plot(nm3, Flambda3)
plt.plot(nm4, Flambda4)
plt.plot(nm5, Flambda5)
plt.plot(nm6, Flambda6)
plt.plot(nm7, Flambda7)
plt.plot(nm8, Flambda8)
plt.plot(nm9, Flambda9)
plt.plot(nm_sun, flux_sun, '--')

plt.xlabel("Wavelength [nm]", fontsize=fz)
plt.title('B III')

ax = plt.gca()
ax.set_yscale('log')

ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

ax.set_ylim(ymin, ymax)
ax.set_xlim(30, 210)

ax2 = ax.twinx()

for i in range(len(b3_nm)):
    ax2.plot((b3_nm[i],b3_nm[i]), (10**(-50),b3_ein[i]), color='black', linestyle='-')

ax2.set_ylim(0,1 )
ax2.tick_params(axis="y",direction="in")
ax2.set_ylabel('Normalized Einstein coefficent', fontsize=fz)
plt.show()
##############################################################
#############################################################
# C I
plt.plot(nm1, Flambda1)
plt.plot(nm2, Flambda2)
plt.plot(nm3, Flambda3)
plt.plot(nm4, Flambda4)
plt.plot(nm5, Flambda5)
plt.plot(nm6, Flambda6)
plt.plot(nm7, Flambda7)
plt.plot(nm8, Flambda8)
plt.plot(nm9, Flambda9)

plt.xlabel("Wavelength [nm]", fontsize=fz)
plt.title('C I')

ax = plt.gca()
ax.set_yscale('log')

ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

ax.set_ylim(ymin, ymax)
ax.set_xlim(90, 200)

ax2 = ax.twinx()

for i in range(len(c1_nm)):
    ax2.plot((c1_nm[i],c1_nm[i]), (10**(-50),c1_ein[i]), color='black', linestyle='-')

ax2.set_ylim(0,1 )
ax2.tick_params(axis="y",direction="in")
ax2.set_ylabel('Normalized Einstein coefficent', fontsize=fz)
plt.show()
##############################################################
#############################################################
# Si II
plt.plot(nm1, Flambda1)
plt.plot(nm2, Flambda2)
plt.plot(nm3, Flambda3)
plt.plot(nm4, Flambda4)
plt.plot(nm5, Flambda5)
plt.plot(nm6, Flambda6)
plt.plot(nm7, Flambda7)
plt.plot(nm8, Flambda8)
plt.plot(nm9, Flambda9)

plt.xlabel("Wavelength [nm]", fontsize=fz)
plt.title('Si II')

ax = plt.gca()
ax.set_yscale('log')

ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

ax.set_ylim(ymin, ymax)
ax.set_xlim(80, 240)

ax2 = ax.twinx()

for i in range(len(si2_nm)):
    ax2.plot((si2_nm[i],si2_nm[i]), (10**(-50),si2_ein[i]), color='black', linestyle='-')

ax2.set_ylim(0,1 )
ax2.tick_params(axis="y",direction="in")
ax2.set_ylabel('Normalized Einstein coefficent', fontsize=fz)
plt.show()
##############################################################
#############################################################
# P II
plt.plot(nm1, Flambda1)
plt.plot(nm2, Flambda2)
plt.plot(nm3, Flambda3)
plt.plot(nm4, Flambda4)
plt.plot(nm5, Flambda5)
plt.plot(nm6, Flambda6)
plt.plot(nm7, Flambda7)
plt.plot(nm8, Flambda8)
plt.plot(nm9, Flambda9)

plt.xlabel("Wavelength [nm]", fontsize=fz)
plt.title('P II')

ax = plt.gca()
ax.set_yscale('log')

ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

ax.set_ylim(ymin, ymax)
ax.set_xlim(125, 155)

ax2 = ax.twinx()

for i in range(len(p2_nm)):
    ax2.plot((p2_nm[i],p2_nm[i]), (10**(-50),p2_ein[i]), color='black', linestyle='-')

ax2.set_ylim(0,1 )
ax2.tick_params(axis="y",direction="in")
ax2.set_ylabel('Normalized Einstein coefficent', fontsize=fz)
plt.show()
##############################################################
#############################################################
# Ca I
plt.plot(nm1, Flambda1)
plt.plot(nm2, Flambda2)
plt.plot(nm3, Flambda3)
plt.plot(nm4, Flambda4)
plt.plot(nm5, Flambda5)
plt.plot(nm6, Flambda6)
plt.plot(nm7, Flambda7)
plt.plot(nm8, Flambda8)
plt.plot(nm9, Flambda9)

plt.xlabel("Wavelength [nm]", fontsize=fz)
plt.title('Ca I')

ax = plt.gca()
ax.set_yscale('log')

ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

ax.set_ylim(ymin, ymax)
ax.set_xlim(210, 660)

ax2 = ax.twinx()

for i in range(len(ca1_nm)):
    ax2.plot((ca1_nm[i],ca1_nm[i]), (10**(-50),ca1_ein[i]), color='black', linestyle='-')

ax2.set_ylim(0,1 )
ax2.tick_params(axis="y",direction="in")
ax2.set_ylabel('Normalized Einstein coefficent', fontsize=fz)
plt.show()
##############################################################
#############################################################
# Sc II
plt.plot(nm1, Flambda1)
plt.plot(nm2, Flambda2)
plt.plot(nm3, Flambda3)
plt.plot(nm4, Flambda4)
plt.plot(nm5, Flambda5)
plt.plot(nm6, Flambda6)
plt.plot(nm7, Flambda7)
plt.plot(nm8, Flambda8)
plt.plot(nm9, Flambda9)

plt.xlabel("Wavelength [nm]", fontsize=fz)
plt.title('Sc II')

ax = plt.gca()
ax.set_yscale('log')

ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

ax.set_ylim(ymin, ymax)
ax.set_xlim(250, 390)

ax2 = ax.twinx()

for i in range(len(sc2_nm)):
    ax2.plot((sc2_nm[i],sc2_nm[i]), (10**(-50),sc2_ein[i]), color='black', linestyle='-')

ax2.set_ylim(0,1 )
ax2.tick_params(axis="y",direction="in")
ax2.set_ylabel('Normalized Einstein coefficent', fontsize=fz)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 64
#      62 plt.plot(nm8, Flambda8)
#      63 plt.plot(nm9, Flambda9)
# ---> 64 plt.plot(nm_sun, flux_sun, '--')
#      66 plt.xlabel("Wavelength [nm]", fontsize=fz)
#      67 plt.title('B III')
#
# NameError: name 'nm_sun' is not defined

# %% [markdown]
# # 11. step: Finding mass-loss rate of stars/the strength of the stellar wind

# %%
a = -22.7
b = 8.96
c = -1.42
k = 29.5            # line force parameter k
mh = 1.6735575*10**(-24)
sun_mass_loss = 1
M = 4.58*1.98*10*(33) 
r = 3.09*6.955*10**(10)
mass_loss = []
z = 0.012
alpha = 0.5

Teff_int = np.linspace(3500, 30000, 54)

for x in Teff_int:
    log_mass_loss = a+b*(x/10**4)+c*((x/10**4)**2)
    mass_loss.append(1*10**(log_mass_loss))

# graph
import matplotlib.pyplot as plt
plt.plot(Teff_int, mass_loss)

ax = plt.gca()
ax.set_yscale('log')

plt.show()

velocity1 = []  # km/s   WRONG

for x in Teff_int:
    velocity1.append(alpha)

# results
#df11 = pd.DataFrame({'T_eff (K)': Teff_int, 'Mass loss rate (solar mass/year)': mass_loss, 'Velocity(km/s)': velocity })
#df11

# %% [markdown]
# # END
